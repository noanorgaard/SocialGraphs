# %%
import re
import html
import os

def extract_genres_from_wikitext(wikitext_content):
    genre_pattern = re.compile(
        r'\|\s*genre\s*=\s*(.*?)(?=\n\s*\||\n}})',
        re.DOTALL | re.IGNORECASE
    )

    link_pattern = re.compile(r'\[\[(?:[^|\]]+\|)?([^\]]+)\]\]')
    citation_pattern = re.compile(r'\{\{cite.*?\}\}', re.DOTALL | re.IGNORECASE)
    template_pattern = re.compile(r'\{\{(?:flatlist|hlist|nowrap)\|?', re.IGNORECASE)
    #ref_tag_pattern = re.compile(r'<ref[^>]*?>.*?</ref>|<ref[^>]*/>', re.DOTALL | re.IGNORECASE)
    ref_tag_pattern = re.compile(r'(<ref[^>]*?>.*?</ref>|<ref[^>]*/>)|(&lt;ref[^&gt;]*?&gt;.*?&lt;/ref&gt;|&lt;ref[^&gt;]*/&gt;)', re.DOTALL | re.IGNORECASE)
    html_comment_pattern = re.compile(r'<!--.*?-->', re.DOTALL)

    match = genre_pattern.search(wikitext_content)
    if match:
        raw_genres = match.group(1)

        # Unescape HTML entities
        raw_genres = html.unescape(raw_genres)

        # Remove HTML tags like <small>, <i>, etc.
        raw_genres = re.sub(r'<[^>]+>', '', raw_genres) 

        # Remove HTML comments, citations, <ref> tags, and nested templates
        raw_genres = html_comment_pattern.sub('', raw_genres)
        raw_genres = citation_pattern.sub('', raw_genres)
        raw_genres = ref_tag_pattern.sub('', raw_genres)
        raw_genres = template_pattern.sub('', raw_genres)

        # Remove lines that look like citation metadata
        raw_genres = re.sub(r'\b(title|url|access-date|publisher|quote|last|first|website|date|archive-url|archive-date|language)\b.*', '', raw_genres)

        # Remove trailing explanations like "The following sources refer to..."
        raw_genres = re.sub(r'(The following.*)', '', raw_genres)

        # Remove stray brackets and asterisks
        raw_genres = raw_genres.replace('[[', '').replace(']]', '')
        raw_genres = raw_genres.replace('{{', '').replace('}}', '')
        raw_genres = raw_genres.replace('*', '')

        # Split by common delimiters
        genre_candidates = re.split(r'\||\n|,', raw_genres)

        # Clean and filter
        genres = []
        for genre in genre_candidates:
            genre = link_pattern.sub(r'\1', genre).strip()
            if genre:
                genres.append(genre)

        return list(set(genres))
    return []

# %%
import re, html

def extract_genres_from_wikitext(wikitext_content):
    # 1) Isolate the 'genre =' field in the infobox
    m = re.search(r'\|\s*genre\s*=\s*(.*?)(?=\n\s*\||\n}})', 
                  wikitext_content, flags=re.DOTALL | re.IGNORECASE)
    if not m:
        return []
    g = m.group(1)

    # 2) Decode HTML entities so &lt;ref&gt; becomes <ref>, etc.
    g = html.unescape(g)

    # 3) Remove HTML comments
    g = re.sub(r'<!--.*?-->', '', g, flags=re.DOTALL)

    # 4) Remove references: self-closing BEFORE paired to avoid cross-line capture
    g = re.sub(r'<ref[^>]*/>', '', g, flags=re.DOTALL | re.IGNORECASE)                     # <ref .../>
    g = re.sub(r'<ref(?:(?!/>)[^>])*?>.*?</ref>', '', g, flags=re.DOTALL | re.IGNORECASE)  # <ref ...>...</ref>

    # 5) Remove citation/footnote templates entirely
    g = re.sub(r'\{\{\s*cite[^{}]*\}\}', '', g, flags=re.IGNORECASE)                       # {{cite web|...}}
    g = re.sub(r'\{\{\s*harv-?nb?[^{}]*\}\}', '', g, flags=re.IGNORECASE)                  # {{harvnb}}, {{harv-nb}}
    g = re.sub(r'\{\{\s*(sfn|sfnb|efn|refn)[^{}]*\}\}', '', g, flags=re.IGNORECASE)        # {{sfn}}, {{refn}}, etc.
    g = re.sub(r'\{\{\s*(citation needed|cn)[^{}]*\}\}', '', g, flags=re.IGNORECASE)       # {{citation needed}}, {{cn}}

    # 6) Drop wrapper templates but keep their inner content
    g = re.sub(r'\{\{\s*(flatlist|hlist|nowrap|plainlist|ubl|unbulleted list)\s*\|?', '', g, flags=re.IGNORECASE)

    # 7) Remove any remaining braces and HTML tags like <small>, <i>, etc.
    g = g.replace('{{', '').replace('}}', '')
    g = re.sub(r'<[^>]+>', '', g)

    # 8) Replace wiki links [[A|B]] -> B; [[A]] -> A
    g = re.sub(r'\[\[(?:[^|\]]+\|)?([^\]]+)\]\]', r'\1', g)

    # 9) Normalize spaces (incl. NBSP) and bullets
    g = g.replace('\xa0', ' ')
    g = g.replace('*', ' ')

    # 10) Split and clean
    parts = re.split(r'[\n,;•·]+|\s*\|\s*', g)
    cleaned = []
    for p in parts:
        t = p.strip()
        if not t:
            continue
        # drop obvious citation metadata leftovers
        if any(k in t.lower() for k in [
            'title=', 'url=', 'access-date', 'publisher=', 'website=',
            'archive-url', 'archive-date', 'language=', 'first=', 'last=',
            'work=', 'date='
        ]):
            continue
        # remove any stranded "citation ..." tail
        t = re.sub(r'\bcitation\b.*', '', t, flags=re.IGNORECASE).strip()
        if t:
            cleaned.append(t)

    # 11) Deduplicate (case-insensitive) while preserving order
    out, seen = [], set()
    for x in cleaned:
        xl = x.lower()
        if xl not in seen:
            seen.add(xl)
            out.append(x)
    return out

# %%
import re, html

def _extract_infobox_genre_value(wikitext: str) -> str | None:
    """
    Find the 'genre =' value from the first 'Infobox musical artist' (or similar) block,
    scanning forward and respecting simple nesting of {{ }}, [[ ]], and <ref>...</ref>.
    Returns the raw text of the genre value (without the leading 'genre ='), or None.
    """
    # Find the first occurrence of '| genre ='
    m = re.search(r'\|\s*genre\s*=\s*', wikitext, flags=re.IGNORECASE)
    if not m:
        return None

    i = m.end()            # start scanning after 'genre ='
    n = len(wikitext)

    # Nesting counters
    tpl_depth = 0          # for {{ ... }}
    link_depth = 0         # for [[ ... ]]
    in_ref = False         # for <ref ...> ... </ref>
    # We'll treat self-closing <ref .../> immediately.

    out_chars = []
    while i < n:
        ch = wikitext[i]

        # --- Handle <ref .../> and <ref>...</ref> ---
        if not in_ref and wikitext.startswith('<ref', i):
            # Self-closing?
            j = wikitext.find('>', i)
            if j == -1:
                # malformed, just break
                break
            # Determine if self-closing
            # scan forward to the '>' we just found and see if immediately before it is '/'
            if wikitext[i:j+1].rstrip().endswith('/>'):
                # consume the whole <ref .../>
                i = j + 1
                continue
            else:
                # enter paired ref; consume the opening tag and set in_ref
                i = j + 1
                in_ref = True
                continue
        if in_ref:
            # consume until '</ref>'
            close_idx = wikitext.lower().find('</ref>', i)
            if close_idx == -1:
                # malformed; drop the rest
                return ''.join(out_chars)
            i = close_idx + len('</ref>')
            in_ref = False
            continue

        # --- Handle {{ ... }} template nesting ---
        if wikitext.startswith('{{', i):
            tpl_depth += 1
            out_chars.append('{{')
            i += 2
            continue
        if wikitext.startswith('}}', i) and tpl_depth > 0:
            tpl_depth -= 1
            out_chars.append('}}')
            i += 2
            continue

        # --- Handle [[ ... ]] link nesting ---
        if wikitext.startswith('[[', i):
            link_depth += 1
            out_chars.append('[[')
            i += 2
            continue
        if wikitext.startswith(']]', i) and link_depth > 0:
            link_depth -= 1
            out_chars.append(']]')
            i += 2
            continue

        # --- End condition: a new parameter line or end of infobox, but only when not nested ---
        if ch == '\n' and tpl_depth == 0 and link_depth == 0 and not in_ref:
            # Look ahead to next non-space character
            j = i + 1
            while j < n and wikitext[j] in ' \t':
                j += 1
            if j < n and wikitext[j] in ['|', '}']:
                # Stop BEFORE this newline — end of 'genre' value
                break

        # Regular character
        out_chars.append(ch)
        i += 1

    return ''.join(out_chars).strip()


def extract_genres_from_wikitext(wikitext_content: str) -> list[str]:
    # 1) Get a robust raw block for the genre value
    raw = _extract_infobox_genre_value(wikitext_content)
    if not raw:
        return []

    # 2) Unescape once so &lt;ref&gt; becomes <ref> etc.
    g = html.unescape(raw)

    # 3) Remove HTML comments
    g = re.sub(r'<!--.*?-->', '', g, flags=re.DOTALL)

    # 4) Remove references: self-closing BEFORE paired
    g = re.sub(r'<ref[^>]*/>', '', g, flags=re.DOTALL | re.IGNORECASE)                    # <ref .../>
    g = re.sub(r'<ref(?:(?!/>)[^>])*?>.*?</ref>', '', g, flags=re.DOTALL | re.IGNORECASE) # <ref ...>...</ref>

    # 5) Remove citation/footnote templates entirely
    g = re.sub(r'\{\{\s*cite[^{}]*\}\}', '', g, flags=re.IGNORECASE)                      # {{cite web|...}}
    g = re.sub(r'\{\{\s*harv-?nb?[^{}]*\}\}', '', g, flags=re.IGNORECASE)                 # {{harvnb}}, {{harv-nb}}
    g = re.sub(r'\{\{\s*(sfn|sfnb|efn|refn)[^{}]*\}\}', '', g, flags=re.IGNORECASE)       # {{sfn}}, {{refn}}, etc.
    g = re.sub(r'\{\{\s*(citation needed|cn)[^{}]*\}\}', '', g, flags=re.IGNORECASE)      # {{citation needed}}, {{cn}}

    # 6) Remove wrapper templates but keep inner content
    g = re.sub(r'\{\{\s*(flatlist|hlist|nowrap|plainlist|ubl|unbulleted list)\s*\|?', '', g, flags=re.IGNORECASE)

    # 7) Remove remaining stray '{{' / '}}' and HTML tags like <small>, <i>, <span>
    g = g.replace('{{', '').replace('}}', '')
    g = re.sub(r'<[^>]+>', '', g)

    # 8) Replace wiki links [[A|B]] -> B ; [[A]] -> A    (allow pipes and newlines within)
    g = re.sub(r'\[\[(?:[^|\]]+?\|)?([^\]]+)\]\]', r'\1', g, flags=re.DOTALL)

    # 9) Normalize whitespace (incl. NBSP) and bullets
    g = g.replace('\xa0', ' ')
    g = g.replace('*', ' ')

    # 10) Split on common separators (commas/newlines/semicolons/pipes/dots)
    parts = re.split(r'[\n,;•·]+|\s*\|\s*', g)

    # 11) Clean and filter
    cleaned = []
    for p in parts:
        t = p.strip()
        if not t:
            continue
        # Drop obvious citation metadata leftovers
        low = t.lower()
        if any(k in low for k in [
            'title=', 'url=', 'access-date', 'publisher=', 'website=',
            'archive-url', 'archive-date', 'language=', 'first=', 'last=',
            'work=', 'date=', 'quote='
        ]):
            continue
        # Remove stranded 'citation ...' tail if any
        t = re.sub(r'\bcitation\b.*', '', t, flags=re.IGNORECASE).strip()

        # Trim non-word chars at ends
        t = re.sub(r'^[\W_]+|[\W_]+$', '', t)
        
        # strip trailing parentheticals
        t = re.sub(r'\s*\([^)]*\)\s*$', '', t)

        if t:
            cleaned.append(t)


    # 12) Dedupe case-insensitively, preserve order
    out, seen = [], set()
    for x in cleaned:
        xl = x.lower()
        if xl not in seen:
            seen.add(xl)
            out.append(x)
    return out

# %%
import re, html

def extract_genres_from_wikitext(wikitext_content):
    # Find the | genre = ... field
    m = re.search(r'\|\s*genre\s*=\s*(.*?)(?=\n\s*\||\n}})', 
                  wikitext_content, flags=re.DOTALL | re.IGNORECASE)
    if not m:
        return []
    g = html.unescape(m.group(1))

    # Remove HTML comments
    g = re.sub(r'<!--.*?-->', '', g, flags=re.DOTALL)

    # Remove refs: self-closing first, then paired (prevents cross-line over-capture)
    g = re.sub(r'<ref[^>]*/>', '', g, flags=re.DOTALL | re.IGNORECASE)                     # <ref .../>
    g = re.sub(r'<ref(?:(?!/>)[^>])*?>.*?</ref>', '', g, flags=re.DOTALL | re.IGNORECASE)  # <ref ...>...</ref>

    # Remove citation/footnote templates entirely
    g = re.sub(r'\{\{\s*cite[^{}]*\}\}', '', g, flags=re.IGNORECASE)                       # {{cite ...}}
    g = re.sub(r'\{\{\s*harv-?nb?[^{}]*\}\}', '', g, flags=re.IGNORECASE)                  # {{harvnb}}
    g = re.sub(r'\{\{\s*(sfn|sfnb|efn|refn)[^{}]*\}\}', '', g, flags=re.IGNORECASE)        # {{sfn}}, {{refn}}, etc.
    g = re.sub(r'\{\{\s*(citation needed|cn)[^{}]*\}\}', '', g, flags=re.IGNORECASE)       # {{citation needed}}

    # Remove wrapper templates but keep their content
    g = re.sub(r'\{\{\s*(flatlist|hlist|nowrap|plainlist|ubl|unbulleted list)\s*\|?', '', g, flags=re.IGNORECASE)

    # Remove any remaining braces and HTML tags
    g = g.replace('{{', '').replace('}}', '')
    g = re.sub(r'<[^>]+>', '', g)

    # Convert wiki-links [[A|B]] -> B; [[A]] -> A
    g = re.sub(r'\[\[(?:[^|\]]+\|)?([^\]]+)\]\]', r'\1', g)

    # Normalize whitespace/NBSP and bullets
    g = g.replace('\xa0', ' ').replace('*', ' ')

    # Split on lines, commas, semicolons, bullets, or pipes
    parts = re.split(r'[\n,;•·]+|\s*\|\s*', g)

    cleaned = []
    for p in parts:
        t = p.strip()
        if not t:
            continue
        # Trim only whitespace and common delimiters (keep parentheses)
        t = re.sub(r'^[\s\-–—,:]+|[\s\-–—,:]+$', '', t)

        # Drop leftover citation metadata
        low = t.lower()
        if any(k in low for k in [
            'title=', 'url=', 'access-date', 'publisher=', 'website=',
            'archive-url', 'archive-date', 'language=', 'first=', 'last=',
            'work=', 'date='
        ]):
            continue
        t = re.sub(r'\bcitation\b.*', '', t, flags=re.IGNORECASE).strip()
        if not t:
            continue

        # Auto-close unmatched '(' → ')'
        if t.count('(') > t.count(')'):
            t = t + ')'

        cleaned.append(t)

    # De-dupe (case-insensitive), preserve order
    out, seen = [], set()
    for x in cleaned:
        xl = x.lower()
        if xl not in seen:
            seen.add(xl)
            out.append(x)
    return out

# %%
import re, html

def extract_genres_from_wikitext(wikitext_content):
    # 1) Isolate the 'genre =' field in the infobox
    m = re.search(r'\|\s*genre\s*=\s*(.*?)(?=\n\s*\||\n}})',
                  wikitext_content, flags=re.DOTALL | re.IGNORECASE)
    if not m:
        return []
    g = m.group(1)

    # 2) Decode HTML entities so &lt;ref&gt; becomes <ref>, etc.
    g = html.unescape(g)

    # 3) Remove HTML comments
    g = re.sub(r'<!--.*?-->', '', g, flags=re.DOTALL)

    # 4) Remove references: self-closing BEFORE paired to avoid cross-line capture
    g = re.sub(r'<ref[^>]*/>', '', g, flags=re.DOTALL | re.IGNORECASE)                      # <ref .../>
    g = re.sub(r'<ref(?:(?!/>)[^>])*?>.*?</ref>', '', g, flags=re.DOTALL | re.IGNORECASE)   # <ref ...>...</ref>

    # 5) Remove citation/footnote templates entirely
    g = re.sub(r'\{\{\s*cite[^{}]*\}\}', '', g, flags=re.IGNORECASE)                        # {{cite web|...}}
    g = re.sub(r'\{\{\s*harv-?nb?[^{}]*\}\}', '', g, flags=re.IGNORECASE)                   # {{harvnb}}, etc.
    g = re.sub(r'\{\{\s*(sfn|sfnb|efn|refn)[^{}]*\}\}', '', g, flags=re.IGNORECASE)         # {{sfn}}, {{refn}}, etc.
    g = re.sub(r'\{\{\s*(citation needed|cn)[^{}]*\}\}', '', g, flags=re.IGNORECASE)        # {{citation needed}}, {{cn}}

    # 6) Drop wrapper templates but keep their inner content
    g = re.sub(r'\{\{\s*(flatlist|hlist|nowrap|plainlist|ubl|unbulleted list)\s*\|?', '',
               g, flags=re.IGNORECASE)

    # 7) Remove remaining braces and HTML tags like <small>, <i>, etc.
    g = g.replace('{{', '').replace('}}', '')
    g = re.sub(r'<[^>]+>', '', g)

    # 8) Replace wiki links [[A|B]] -> B; [[A]] -> A
    g = re.sub(r'\[\[(?:[^|\]]+\|)?([^\]]+)\]\]', r'\1', g)

    # 9) Normalize whitespace (incl. NBSP) and bullets
    g = g.replace('\xa0', ' ')
    g = g.replace('*', ' ')

    # 10) Split on common delimiters
    parts = re.split(r'[\n,;•·]+|\s*\|\s*', g)

    def normalize_label(t: str) -> str:
        # Trim surrounding punctuation
        t = t.strip()
        t = re.sub(r'^[\W_]+|[\W_]+$', '', t)
        if not t:
            return ''

        # Drop obvious citation metadata leftovers
        lo = t.lower()
        if any(k in lo for k in [
            'title=', 'url=', 'access-date', 'publisher=', 'website=',
            'archive-url', 'archive-date', 'language=', 'first=', 'last=',
            'work=', 'date='
        ]):
            return ''

        # Remove any stranded "citation ..." tails
        t = re.sub(r'\bcitation\b.*', '', t, flags=re.IGNORECASE).strip()

        # --- Strip parenthetical qualifiers anywhere (e.g., "rock (early)" → "rock") ---
        # Remove ALL (...) groups; repeat to be safe if multiple occur
        t = re.sub(r'\s*\([^)]*\)', '', t).strip()

        # Lowercase everything
        t = t.lower()

        # --- Normalize rock and roll variants to a single label ---
        # rock & roll / rock and roll / rock 'n' roll / rock ’n’ roll → "rock and roll"
        t = re.sub(r"rock\s*(?:&|and|['`´’]\s*n['`´’])\s*roll", "rock and roll", t)

        # Collapse repeated whitespace
        t = re.sub(r'\s{2,}', ' ', t)

        return t

    cleaned = [normalize_label(p) for p in parts]
    cleaned = [c for c in cleaned if c]

    # 11) Deduplicate (already lowercase) while preserving order
    out, seen = [], set()
    for x in cleaned:
        if x not in seen:
            seen.add(x)
            out.append(x)
    return out

# %%
import re
import html

def extract_genres_from_wikitext(wikitext_content):
    """
    Extract a cleaned, normalized list of genres from Wikipedia-like wikitext.
    - Removes refs, citation templates, wrapper templates, HTML, and wiki links.
    - Strips all parenthetical qualifiers (e.g., '(early)', '(late)') and broken tails.
    - Lowercases all genres.
    - Normalizes common variants (rock & roll, r&b, hip-hop, post punk, synth pop, etc.).
    - Drops obvious template/config noise.
    - Deduplicates while preserving order.
    """
    # 1) Isolate the 'genre =' field in the infobox
    m = re.search(
        r'\|\s*genre\s*=\s*(.*?)(?=\n\s*\||\n}})',
        wikitext_content,
        flags=re.DOTALL | re.IGNORECASE
    )
    if not m:
        return []
    g = m.group(1)

    # 2) Decode HTML entities (&lt;ref&gt; -> <ref>, &amp; -> &, etc.)
    g = html.unescape(g)

    # 3) Remove HTML comments
    g = re.sub(r'<!--.*?-->', '', g, flags=re.DOTALL)

    # 4) Remove references: self-closing BEFORE paired to avoid cross-line capture
    g = re.sub(r'<ref[^>]*/>', '', g, flags=re.DOTALL | re.IGNORECASE)                      # <ref .../>
    g = re.sub(r'<ref(?:(?!/>)[^>])*?>.*?</ref>', '', g, flags=re.DOTALL | re.IGNORECASE)   # <ref ...>...</ref>

    # 5) Remove citation/footnote templates entirely
    g = re.sub(r'\{\{\s*cite[^{}]*\}\}', '', g, flags=re.IGNORECASE)                        # {{cite web|...}}
    g = re.sub(r'\{\{\s*harv-?nb?[^{}]*\}\}', '', g, flags=re.IGNORECASE)                   # {{harvnb}}, {{harv-nb}}
    g = re.sub(r'\{\{\s*(sfn|sfnb|efn|refn)[^{}]*\}\}', '', g, flags=re.IGNORECASE)         # {{sfn}}, {{refn}}, etc.
    g = re.sub(r'\{\{\s*(citation needed|cn)[^{}]*\}\}', '', g, flags=re.IGNORECASE)        # {{citation needed}}, {{cn}}

    # 6) Drop wrapper templates but keep their inner content
    g = re.sub(r'\{\{\s*(flatlist|hlist|nowrap|plainlist|ubl|unbulleted list)\s*\|?', '',
               g, flags=re.IGNORECASE)

    # 7) Remove remaining braces and HTML tags like <small>, <i>, etc.
    g = g.replace('{{', '').replace('}}', '')
    g = re.sub(r'<[^>]+>', '', g)

    # 8) Replace wiki links [[A|B]] -> B; [[A]] -> A
    g = re.sub(r'\[\[(?:[^|\]]+\|)?([^\]]+)\]\]', r'\1', g)

    # 9) Normalize whitespace (incl. NBSP) and bullets
    g = g.replace('\xa0', ' ')
    g = g.replace('*', ' ')

    # 10) Split on common delimiters
    parts = re.split(r'[\n,;•·]+|\s*\|\s*', g)

    # --- Normalization helpers ---

    # Canonical mapping for near-duplicates and synonyms (all keys/values lowercase)
    CANON_MAP = {
        # rock and roll family
        "rock & roll": "rock and roll",
        "rock and roll": "rock and roll",
        "rock 'n' roll": "rock and roll",
        "rock ’n’ roll": "rock and roll",
        "rock `n` roll": "rock and roll",

        # r&b / rhythm & blues
        "r&b": "rhythm and blues",
        "r & b": "rhythm and blues",
        "rhythm & blues": "rhythm and blues",

        # hip hop
        "hip-hop": "hip hop",
        "hip–hop": "hip hop",

        # hyphen/space variants
        "post punk": "post-punk",
        "synth pop": "synth-pop",
        "dance rock": "dance-rock",
        "blue eyed soul": "blue-eyed soul",

        # AOR
        "aor": "album-oriented rock",
    }

    # Regexes for pattern families
    ROCKNROLL_RX = re.compile(r"rock\s*(?:&|and|['`´’]\s*n['`´’])\s*roll")
    HIPHOP_RX    = re.compile(r"hip\s*[-–]?\s*hop")
    RAND_B_RX    = re.compile(r"(?:^|\b)r\s*&\s*b(?:\b|$)|rhythm\s*&\s*blues")

    # Token acceptability: letters (incl. accents), numbers, space, hyphen, apostrophes/quotes, ampersand, dots
    ALLOWED_RX   = re.compile(r"^[0-9A-Za-zÀ-ÖØ-öø-ÿ\s\-\&'`´’\.]+$")

    # Substrings indicating template/config noise to drop
    DROP_SUBSTRS = [
        'citation', 'cite', 'access-date', 'archive-url', 'archive-date',
        'publisher=', 'website=', 'title=', 'url=', 'first=', 'last=',
        'class=', 'nowrap', 'italic', 'lang', 'script=', 'format='
    ]

    def normalize_label(t: str) -> str:
        # Trim punctuation
        t = t.strip()
        t = re.sub(r'^[\W_]+|[\W_]+$', '', t)
        if not t:
            return ''

        # Drop obvious noise
        lo = t.lower()
        if any(s in lo for s in DROP_SUBSTRS):
            return ''

        # Remove any parenthetical parts, even if multiple (e.g., "(early)", "(later)")
        t = re.sub(r'\s*\([^)]*\)', '', t).strip()
        # If an unmatched '(' tail remains, drop that too (e.g., "funk metal (early")
        t = re.sub(r'\s*\([^)]*$', '', t).strip()

        # Lowercase
        t = t.lower()

        # Normalize rock and roll forms
        if ROCKNROLL_RX.search(t):
            t = ROCKNROLL_RX.sub('rock and roll', t)

        # Normalize hip hop forms
        if HIPHOP_RX.search(t):
            t = HIPHOP_RX.sub('hip hop', t)

        # Normalize r&b / rhythm & blues
        if RAND_B_RX.search(t):
            t = 'rhythm and blues'

        # Apply canonical map (covers aor, synth-pop, post-punk, blue-eyed soul, dance-rock, etc.)
        t = CANON_MAP.get(t, t)

        # Reject invalid tokens (after normalization)
        if not ALLOWED_RX.match(t):
            return ''

        # Collapse repeated spaces and strip stray punctuation
        t = re.sub(r'\s{2,}', ' ', t).strip('. ').strip()

        return t

    cleaned = [normalize_label(p) for p in parts]
    cleaned = [c for c in cleaned if c]

    # Deduplicate while preserving order (already lowercase)
    out, seen = [], set()
    for x in cleaned:
        if x not in seen:
            seen.add(x)
            out.append(x)
    return out

# %%
# Define the directory where your band data files are located
data_directory = "Bands"
band_genres = {}

# Iterate over all files in the specified directory
for filename in os.listdir(data_directory):
    file_path = os.path.join(data_directory, filename)
    band_name = os.path.splitext(filename)[0] # Get band name from filename

    try:
        with open(file_path, 'r', encoding='utf-8') as f:
            content = f.read()

            wikitext_content = content

            genres = extract_genres_from_wikitext(wikitext_content)
            band_genres[band_name] = genres
    except Exception as e:
        print(f"Error processing file {filename}: {e}")

# order the band list alphabetically
band_genres = dict(sorted(band_genres.items()))

# print number of bands that have infoboxes:
num_bands_with_infoboxes = sum(1 for genres in band_genres.values() if genres)
print(f"Number of bands with infoboxes: {num_bands_with_infoboxes} \n")

# Print the extracted genres for each band
for band, genres in band_genres.items():
    print(f"{band}: {genres}")
# Out:
# Number of bands with infoboxes: 472
#
# 10_Years__band_: ['alternative metal', 'progressive metal', 'post-grunge', 'nu metal']
# 10cc: ['art rock', 'art pop', 'progressive pop', 'soft rock', 'pop rock']
# 311__band_: ['alternative rock', 'rap rock', 'reggae rock', 'funk rock', 'funk metal']
# 38_Special__band_: ['hard rock', 'southern rock', 'boogie rock', 'blues rock']
# 3_Doors_Down: ['post-grunge', 'hard rock', 'alternative rock']
# ABBA: ['pop', 'disco', 'pop rock', 'europop']
# AC_DC: ['hard rock', 'blues rock', 'rock and roll', 'heavy metal']
# AFI__band_: ['punk rock', 'gothic rock', 'horror punk', 'post-hardcore', 'emo', 'hardcore punk']
# A_Perfect_Circle: ['alternative rock', 'alternative metal', 'hard rock', 'art rock']
# Accept__band_: ['heavy metal']
# Adam_Ant: ['new wave', 'post-punk', 'alternative rock', 'dance-rock']
# Aerosmith: ['hard rock', 'blues rock', 'heavy metal']
# Air_Supply: ['soft rock', 'pop rock', 'pop', 'adult contemporary', 'middle-of-the-road']
# Alanis_Morissette: ['alternative rock', 'post-grunge', 'electronica', 'grunge', 'trip hop', 'indie pop', 'pop rock']
# Alice_Cooper: ['hard rock', 'shock rock', 'glam rock', 'heavy metal']
# Alice_Cooper__band_: ['hard rock', 'glam rock', 'shock rock', 'psychedelic rock']
# Alice_in_Chains: ['grunge', 'alternative metal', 'heavy metal', 'alternative rock', 'sludge metal']
# Alter_Bridge: ['hard rock', 'heavy metal', 'alternative metal', 'progressive metal', 'alternative rock', 'post-grunge']
# Ambrosia__band_: ['progressive rock', 'soft rock', 'jazz fusion', 'blue-eyed soul']
# America__band_: ['soft rock', 'folk rock', 'pop rock', 'country rock']
# Anthrax__American_band_: ['thrash metal', 'heavy metal', 'groove metal', 'alternative metal']
# April_Wine: ['hard rock']
# Arcade_Fire: ['indie rock', 'art rock', 'dance-rock', 'baroque pop']
# Arctic_Monkeys: ['indie rock', 'garage rock', 'post-punk revival', 'psychedelic rock', 'alternative rock', 'lounge pop']
# Asia__band_: ['progressive rock', 'album-oriented rock', 'pop rock']
# Audioslave: ['hard rock', 'alternative metal', 'post-grunge', 'alternative rock']
# Avenged_Sevenfold: ['heavy metal', 'progressive metal', 'alternative metal', 'hard rock', 'metalcore']
# Avril_Lavigne: ['pop-punk', 'alternative rock', 'pop rock', 'pop']
# Awolnation: ['alternative rock', 'electronic rock', 'indie rock', 'electropop', 'pop rock', 'dance-rock']
# Bachman_Turner_Overdrive: ['rock', 'hard rock', 'boogie rock']
# Bad_Company: ['hard rock', 'blues rock']
# Badfinger: ['rock', 'power pop']
# Barenaked_Ladies: ['alternative pop', 'folk rock', 'pop rock', 'comedy rock']
# Bay_City_Rollers: ['pop', 'glam rock', 'pop rock']
# Beastie_Boys: ['hip hop', 'rap rock', 'alternative hip hop', 'hardcore punk']
# Beck: ['alternative rock', 'folk rock', 'psychedelia', 'electronic', 'alt-country', 'lo-fi']
# Bee_Gees: ['pop', 'soul', 'disco', 'rock', 'soft rock']
# Ben_Folds_Five: ['alternative rock', 'power pop']
# Bill_Haley___His_Comets: ['rock and roll', 'rockabilly', 'western swing']
# Billy_Idol: ['new wave', 'hard rock', 'pop rock', 'punk rock']
# Billy_Joel: ['rock', 'soft rock', 'pop rock']
# Billy_Squier: ['hard rock', 'arena rock', 'pop rock', 'power pop']
# Billy_Talent: ['punk rock', 'alternative rock', 'post-hardcore', 'pop-punk']
# Black_Sabbath: ['heavy metal']
# Black_Stone_Cherry: ['hard rock', 'southern rock']
# Black_Veil_Brides: ['hard rock', 'alternative metal', 'glam metal', 'gothic metal', 'metalcore']
# Blink-182: ['pop-punk', 'punk rock', 'skate punk', 'alternative rock']
# Blondie__band_: ['new wave', 'punk rock', 'pop rock', 'pop', 'disco']
# Bloodhound_Gang: ['alternative rock', 'rap rock', 'pop-punk', 'new wave']
# Blue_October: ['alternative rock', 'art rock', 'post-grunge', 'new wave', 'synth-pop', 'shoegaze']
# Blue_Öyster_Cult: ['hard rock', 'heavy metal', 'occult rock', 'psychedelic rock', 'progressive rock', 'acid rock']
# Blues_Traveler: ['blues rock', 'folk rock', 'alternative rock', 'southern rock', 'jam band']
# Blur__band_: ['britpop', 'indie rock', 'alternative rock', 'art pop']
# Bo_Diddley: ['rock and roll', 'blues', 'psychedelic funk']
# Bob_Dylan: ['folk', 'blues', 'rock', 'gospel', 'country', 'traditional pop']
# Bob_Seger: ['rock', 'heartland rock', 'roots rock']
# Bon_Jovi: ['hard rock', 'glam metal', 'arena rock', 'pop rock']
# Boston__band_: ['hard rock', 'arena rock']
# Bowling_for_Soup: ['pop-punk', 'pop rock', 'alternative rock', 'power pop']
# Boys_Like_Girls: ['flat list', 'pop rock', 'pop-punk', 'emo pop', 'alternative rock']
# Bread__band_: ['soft rock']
# Breaking_Benjamin: ['hard rock', 'post-grunge', 'alternative metal', 'alternative rock']
# Bring_Me_the_Horizon: ['metalcore', 'alternative metal', 'alternative rock', 'post-hardcore', 'pop rock', 'electronic rock', 'deathcore']
# Bruce_Springsteen: ['flat list', 'rock', 'heartland rock', 'folk', 'pop rock']
# Bryan_Adams: ['rock', 'pop rock', 'soft rock', 'arena rock', 'heartland rock']
# Bryan_Ferry: ['pop rock', 'glam rock', 'art rock', 'sophisti-pop']
# Buckcherry: ['hard rock', 'alternative metal', 'sleaze rock']
# Buddy_Holly: ['rock and roll', 'rockabilly', 'pop']
# Bullet_for_My_Valentine: ['melodic metalcore', 'heavy metal', 'thrash metal', 'hard rock']
# Bush__British_band_: ['post-grunge', 'grunge', 'hard rock', 'alternative rock']
# Cage_the_Elephant: ['alternative rock', 'indie rock', 'psychedelic rock', 'garage rock', 'punk blues', 'post-punk']
# Cake__band_: ['alternative rock', 'country', 'indie rock', 'funk rock']
# Canned_Heat: ['blues rock', 'boogie rock']
# Catfish_and_the_Bottlemen: ['alternative rock', 'indie rock', 'post-punk revival']
# Charlie_Daniels: ['southern rock', 'country rock', 'progressive country', 'bluegrass']
# Cheap_Trick: ['rock', 'hard rock', 'power pop']
# Chevelle__band_: ['hard rock', 'alternative metal', 'alternative rock', 'post-grunge', 'nu metal']
# Chicago__band_: ['rock', 'soft rock', 'pop rock', 'jazz rock']
# Chris_Cornell: ['alternative metal', 'heavy metal', 'grunge', 'alternative rock', 'hard rock']
# Chris_Rea: ['pop rock', 'soft rock', 'electric blues', 'blues rock']
# Chris_de_Burgh: ['art rock', 'pop', 'soft rock']
# Christopher_Cross: ['rock', 'pop', 'soft rock', 'yacht rock']
# Chubby_Checker: ['rock and roll']
# Chuck_Berry: ['rock and roll', 'rhythm and blues']
# Cinderella__band_: ['glam metal', 'hard rock', 'blues rock']
# Coheed_and_Cambria: ['progressive rock', 'alternative rock', 'post-hardcore', 'emo', 'progressive metal']
# Cold_Chisel: ['pub rock', 'rhythm and blues', 'hard rock', 'rock and roll']
# Coldplay: ['alternative rock', 'pop rock', 'post-britpop', 'pop']
# Collective_Soul: ['alternative rock', 'hard rock', 'post-grunge']
# Counting_Crows: ['alternative rock', 'roots rock', 'pop rock']
# Crash_Test_Dummies: ['alternative rock', 'folk rock']
# Cream__band_: ['psychedelic rock', 'blues rock', 'acid rock', 'hard rock', 'jam rock']
# Creed__band_: ['post-grunge', 'hard rock', 'alternative rock', 'alternative metal']
# Creedence_Clearwater_Revival: ['swamp rock', 'roots rock', 'blues rock', 'country rock', 'southern rock']
# Crowded_House: ['pop rock', 'jangle pop', 'alternative rock']
# Dallas_Green__musician_: []
# Damn_Yankees__band_: ['hard rock', 'arena rock', 'glam metal']
# Dan_Fogelberg: ['rock', 'country', 'folk', 'folk rock', 'soft rock', 'pop rock', 'pop']
# Dashboard_Confessional: ['emo', 'alternative rock', 'indie rock', 'acoustic rock']
# Daughtry__band_: ['post-grunge', 'hard rock', 'pop rock']
# Dave_Matthews_Band: ['rock', 'jam rock']
# David_Bowie: ['art rock', 'glam rock', 'pop', 'electronic']
# Days_of_the_New: ['post-grunge', 'alternative rock', 'grunge', 'acoustic rock', 'alternative metal']
# Death_Cab_for_Cutie: ['indie rock', 'alternative rock', 'indie pop', 'emo']
# Deep_Purple: ['hard rock', 'heavy metal', 'progressive rock']
# Def_Leppard: ['hard rock', 'glam metal', 'arena rock', 'power pop', 'heavy metal']
# Deftones: ['alternative metal', 'art rock', 'shoegaze', 'nu metal']
# Depeche_Mode: ['synth-pop', 'alternative dance', 'alternative rock', 'dance-rock', 'dark wave', 'edm', 'electronic rock', 'industrial', 'new wave', 'pop rock', 'post-punk']
# Dio__band_: ['heavy metal']
# Dire_Straits: ['roots rock', 'blues rock', 'pub rock']
# Disturbed__band_: ['heavy metal', 'alternative metal', 'hard rock', 'nu metal']
# Don_Henley: ['rock', 'country rock', 'pop rock', 'hard rock', 'folk rock']
# Donovan: ['folk', 'pop', 'psychedelia', 'rock']
# Dr__Hook___the_Medicine_Show: ['country rock', 'roots rock', 'boogie rock', 'pop rock', 'soft rock', 'blue-eyed soul', 'disco']
# Dropkick_Murphys: ['celtic punk', 'folk punk', 'street punk', 'oi', 'hardcore punk']
# Drowning_Pool: ['alternative metal', 'nu metal', 'hard rock', 'post-grunge']
# Duane_Eddy: ['instrumental rock', 'rockabilly', 'rock and roll', 'country']
# Duran_Duran: ['pop rock', 'synth-pop', 'new wave', 'dance-rock']
# Eagles__band_: ['rock', 'country rock', 'soft rock', 'folk rock']
# Echo___the_Bunnymen: []
# Eddie_Cochran: ['rock and roll', 'rockabilly', 'country', 'rhythm and blues']
# Eddie_Money: ['rock', 'pop rock', 'hard rock']
# Edgar_Winter: ['southern rock', 'pop', 'jazz fusion', 'blues rock', 'blue-eyed soul', 'boogie rock']
# Electric_Light_Orchestra: []
# Elton_John: ['pop rock', 'glam rock', 'soft rock', 'blues']
# Elvis_Costello: ['rock', 'pop', 'new wave', 'power pop', 'punk rock', 'pub rock']
# Elvis_Presley: ['rock and roll', 'pop', 'rockabilly', 'country', 'gospel', 'rhythm and blues', 'soul', 'blues']
# Emerson__Lake___Palmer: []
# England_Dan___John_Ford_Coley: []
# Eric_Clapton: ['rock', 'blues']
# Europe__band_: ['arena rock', 'hard rock', 'glam metal', 'blues rock', 'heavy metal']
# Evanescence: ['alternative metal', 'gothic metal', 'gothic rock', 'hard rock', 'industrial rock', 'symphonic metal', 'nu metal']
# Everclear__band_: ['alternative rock', 'power pop', 'post-grunge', 'pop rock', 'grunge', 'punk rock']
# Everlast: ['hip hop', 'folk rock', 'blues']
# Extreme__band_: ['hard rock', 'funk metal', 'glam metal']
# Faces__band_: ['rock', 'blues']
# Faith_No_More: ['alternative metal', 'funk metal', 'alternative rock', 'experimental rock']
# Fall_Out_Boy: ['pop-punk', 'pop rock', 'emo', 'alternative rock']
# Fats_Domino: ['rock and roll', 'rhythm and blues', 'boogie-woogie', 'blues']
# Filter__band_: ['industrial rock', 'post-grunge', 'alternative rock', 'hard rock', 'industrial metal', 'alternative metal']
# Finger_Eleven: ['alternative rock', 'alternative metal', 'post-grunge', 'hard rock', 'nu metal']
# FireHouse: ['glam metal', 'hard rock']
# Five_Finger_Death_Punch: ['groove metal', 'alternative metal', 'hard rock']
# Five_for_Fighting: ['soft rock', 'heartland rock', 'alternative rock', 'pop rock', 'americana', 'adult contemporary']
# Fleetwood_Mac: ['pop rock', 'soft rock', 'blues rock', 'art pop']
# Flogging_Molly: ['celtic punk', 'folk punk']
# Florence_and_the_Machine: ['indie rock', 'indie pop', 'chamber pop', 'baroque pop', 'art pop', 'art rock', 'neo soul', 'folk']
# Flyleaf__band_: ['alternative rock', 'post-grunge', 'hard rock', 'alternative metal', 'christian rock']
# Foals__band_: ['indie rock', 'alternative rock', 'math rock', 'art rock', 'dance-punk']
# Foo_Fighters: ['alternative rock', 'post-grunge', 'hard rock']
# Foreigner__band_: ['hard rock', 'soft rock', 'arena rock']
# Foster_the_People: ['indie pop', 'synth-pop', 'dance-pop', 'alternative rock', 'indie rock', 'neo-psychedelia']
# Frank_Zappa: ['rock', 'progressive rock', 'blues', 'experimental', 'jazz', 'fusion', 'classical', 'pop', 'avant-garde', 'doo-wop', 'comedy', 'electronic', 'musique concrète']
# Franz_Ferdinand__band_: ['indie rock', 'post-punk revival', 'dance-punk', 'art rock', 'art punk']
# Fuel__band_: ['alternative rock', 'hard rock', 'post-grunge', 'alternative metal']
# Fun__band_: ['indie pop', 'indie rock', 'pop rock', 'baroque pop']
# Funkadelic: ['funk rock', 'psychedelic funk', 'acid rock', 'psychedelic rock']
# Garbage__band_: ['alternative rock', 'electronic rock', 'dance-rock', 'trip hop', 'industrial rock']
# Gary_Glitter: ['glam rock', 'rock and roll', 'pop rock', 'hard rock', 'disco']
# Gene_Vincent: ['flat list', 'rockabilly', 'rock and roll', 'country']
# Genesis__band_: ['progressive rock', 'art rock', 'pop rock', 'soft rock']
# George_Harrison: ['rock', 'pop', 'indian classical']
# George_Thorogood: ['blues rock', 'hard rock', 'boogie rock', 'rock and roll']
# Ghost__Swedish_band_: ['hard rock', 'heavy metal', 'arena rock', 'pop rock', 'progressive rock']
# Gin_Blossoms: ['alternative rock', 'jangle pop', 'power pop', 'post-grunge', 'country rock']
# Glenn_Frey: ['rock', 'pop rock', 'soft rock', 'country rock', 'hard rock']
# Godsmack: ['alternative metal', 'hard rock', 'post-grunge', 'nu metal']
# Golden_Earring: ['hard rock', 'blues rock', 'jazz rock', 'psychedelic rock', 'garage rock']
# Goo_Goo_Dolls: ['alternative rock', 'pop rock', 'post-grunge', 'punk rock']
# Good_Charlotte: ['pop-punk', 'alternative rock', 'emo', 'pop rock']
# Grand_Funk_Railroad: ['hard rock arena rock']
# Grateful_Dead: ['rock']
# Great_White: ['hard rock', 'glam metal']
# Green_Day: ['punk rock', 'pop-punk', 'alternative rock', 'skate punk', 'power pop']
# Greta_Van_Fleet: ['hard rock', 'blues rock', 'progressive rock']
# Guns_N__Roses: ['hard rock', 'heavy metal']
# Halestorm: ['hard rock', 'heavy metal', 'alternative metal', 'post-grunge', 'alternative rock']
# Hall___Oates: []
# Harry_Chapin: ['flat list', 'folk rock', 'pop rock']
# Harry_Nilsson: ['rock', 'pop']
# Heart__band_: ['rock', 'hard rock', 'folk rock', 'pop rock']
# Herman_s_Hermits: ['beat', 'pop rock', 'bubblegum']
# Highly_Suspect: ['alternative rock', 'hard rock', 'blues rock', 'grunge', 'garage rock']
# Hinder: ['post-grunge', 'hard rock']
# Hole__band_: ['alternative rock', 'grunge', 'punk rock', 'noise rock', 'power pop']
# Hoobastank: ['alternative rock', 'nu metal', 'post-grunge', 'funk metal', 'ska punk']
# Hootie___the_Blowfish: []
# Huey_Lewis_and_the_News: ['rock', 'new wave', 'rhythm and blues', 'doo-wop']
# INXS: ['new wave', 'pub rock', 'dance-rock', 'funk rock', 'alternative rock']
# Ian_Dury: ['new wave', 'punk rock', 'post-punk', 'funk', 'disco', 'pub rock']
# Icehouse__band_: ['rock', 'new wave', 'synth-pop']
# Iggy_Pop: ['rock', 'punk rock', 'proto-punk', 'hard rock', 'garage rock']
# Imagine_Dragons: ['pop rock', 'electropop', 'pop', 'arena rock', 'alternative rock', 'indie pop']
# Incubus__band_: ['alternative rock', 'alternative metal', 'funk metal', 'nu metal']
# Interpol__band_: ['indie rock', 'post-punk revival']
# Iron_Maiden: ['heavy metal']
# Jack_White: ['blues rock', 'garage rock revival', 'alternative rock', 'punk blues', 'folk', 'country', 'experimental rock']
# Jackson_Browne: ['flat list', 'rock', 'folk rock', 'soft rock', 'pop rock', 'country rock']
# Royal_Blood__band_: ['hard rock', 'blues rock', 'garage rock', 'stoner rock', 'alternative rock']
# Run-DMC: ['hip hop', 'rap rock']
# Rush__band_: ['progressive rock', 'hard rock', 'heavy metal']
# Saliva__band_: ['nu metal', 'post-grunge', 'alternative metal', 'rap metal', 'hard rock']
# Sam_Fender: ['rock', 'indie rock', 'pop rock', 'heartland rock']
# Santana__band_: ['latin rock', 'blues rock', 'psychedelic rock', 'acid rock', 'chicano rock', 'jazz fusion', 'yacht rock']
# Saving_Abel: ['rock', 'hard rock', 'post-grunge', 'southern rock']
# Scorpions__band_: ['hard rock', 'heavy metal']
# Seether: ['post-grunge', 'hard rock', 'alternative metal', 'alternative rock', 'nu metal']
# Sepultura: ['groove metal', 'thrash metal', 'death metal', 'alternative metal']
# Sex_Pistols: ['punk rock']
# Shakin__Stevens: ['rockabilly', 'rock and roll']
# Sheryl_Crow: ['country rock', 'pop', 'folk', 'blues', 'heartland rock']
# Shinedown: ['hard rock', 'alternative metal', 'post-grunge', 'alternative rock', 'pop rock']
# Silverchair: ['alternative rock', 'grunge', 'art rock', 'post-grunge']
# Simon___Garfunkel: []
# Simple_Minds: ['post-punk', 'art rock', 'arena rock', 'synth-pop']
# Simple_Plan: ['pop-punk', 'alternative rock', 'pop rock', 'power pop', 'emo']
# Sixto_Rodriguez: ['folk rock', 'psychedelic folk', 'psychedelic rock']
# Skid_Row__American_band_: ['heavy metal', 'hard rock', 'glam metal']
# Skillet__band_: ['christian rock', 'hard rock', 'alternative rock', 'alternative metal', 'post-grunge', 'nu metal']
# Slade: ['glam rock hard rock']
# Slayer: ['thrash metal']
# Slipknot__band_: ['nu metal', 'alternative metal', 'groove metal']
# Sly_and_the_Family_Stone: ['psychedelic soul', 'funk', 'rock', 'progressive soul']
# Small_Faces: ['rock', 'rhythm and blues', 'beat', 'pop', 'psychedelia', 'proto-punk', 'progressive pop']
# Smash_Mouth: ['alternative rock', 'power pop', 'pop rock', 'ska punk']
# Smokie__band_: ['pop rock', 'soft rock', 'glam rock']
# Snow_Patrol: ['alternative rock', 'power pop', 'post-britpop', 'indie rock']
# Social_Distortion: ['punk rock', 'cowpunk', 'rock and roll', 'hardcore punk']
# Sonic_Youth: ['noise rock', 'alternative rock', 'experimental rock', 'indie rock', 'post-punk', 'no wave']
# Soundgarden: ['grunge', 'heavy metal', 'alternative metal', 'alternative rock']
# Staind: ['alternative metal', 'post-grunge', 'nu metal', 'hard rock']
# Starset: ['alternative rock', 'electronic rock', 'hard rock', 'alternative metal', 'progressive rock']
# Starship__band_: ['rock', 'arena rock', 'pop rock']
# Status_Quo__band_: ['rock', 'boogie rock', 'hard rock', 'psychedelia']
# Steely_Dan: ['jazz rock', 'yacht rock', 'soft rock', 'pop', 'jazz fusion']
# Steppenwolf__band_: ['psychedelic rock', 'blues rock', 'acid rock', 'hard rock', 'heavy metal', 'garage rock']
# Steve_Miller_Band: ['blues rock', 'psychedelic rock', 'pop rock']
# Steve_Vai: ['instrumental rock', 'hard rock', 'heavy metal', 'progressive metal']
# Steve_Winwood: ['blue-eyed soul', 'rhythm and blues', 'rock', 'pop']
# Stevie_Nicks: ['rock', 'pop', 'folk']
# Stevie_Ray_Vaughan: ['flat list', 'texas blues', 'blues rock', 'electric blues', 'rock and roll']
# Sting__musician_: ['pop', 'new wave', 'soft rock']
# Stone_Sour: ['alternative metal', 'hard rock', 'post-grunge', 'alternative rock']
# Stone_Temple_Pilots: ['alternative rock', 'grunge', 'hard rock', 'alternative metal', 'psychedelic rock']
# Styx__band_: ['progressive rock', 'art rock', 'hard rock', 'arena rock', 'pop rock']
# Sublime__band_: ['ska punk', 'reggae rock']
# Sublime_with_Rome: ['reggae rock', 'alternative rock', 'hip hop', 'dub', 'ska punk', 'punk rock']
# Sum_41: ['pop-punk', 'skate punk', 'punk rock', 'alternative metal', 'melodic hardcore', 'alternative rock']
# Supertramp: ['flat list', 'progressive pop', 'progressive rock', 'soft rock', 'pop']
# Survivor__band_: ['rock', 'arena rock', 'hard rock']
# System_of_a_Down: ['alternative metal', 'nu metal', 'hard rock', 'progressive metal']
# T__Rex__band_: ['glam rock', 'pop', 'psychedelic folk']
# Talking_Heads: ['new wave', 'post-punk', 'avant-funk', 'art pop', 'worldbeat']
# Ted_Nugent: ['hard rock']
# Ten_Years_After: ['blues rock']
# Tenacious_D: ['comedy rock', 'acoustic rock', 'hard rock', 'heavy metal']
# Tesla__band_: ['hard rock', 'blues rock', 'glam metal']
# The_Alan_Parsons_Project: ['progressive rock', 'art rock', 'progressive pop', 'soft rock']
# The_All-American_Rejects: ['pop-punk', 'power pop', 'alternative rock', 'pop rock', 'emo pop']
# The_Allman_Brothers_Band: ['southern rock', 'blues rock', 'jazz rock', 'jam band']
# The_Animals: ['blues rock']
# The_B-52_s: []
# The_Band: ['roots rock', 'americana', 'folk rock', 'country rock']
# The_Bangles: ['pop rock', 'power pop', 'new wave', 'paisley underground']
# The_Beach_Boys: ['rock', 'pop', 'surf', 'psychedelia']
# The_Beatles: ['rock', 'pop', 'beat', 'psychedelia']
# The_Big_Bopper: ['rock and roll', 'rockabilly', 'country']
# The_Black_Crowes: ['southern rock', 'blues rock', 'hard rock', 'roots rock', 'jam band']
# The_Black_Keys: ['garage rock', 'blues rock', 'punk blues', 'indie rock']
# The_Boxtones: ['rock']
# The_Byrds: ['flat list', 'rock', 'pop', 'folk rock', 'psychedelia', 'raga rock', 'country rock', 'jangle pop']
# The_Cab: ['alternative rock', 'pop punk', 'pop rock', 'power pop', 'emo pop', 'pop']
# The_Cardigans: ['alternative rock', 'pop rock', 'indie rock', 'indie pop']
# The_Cars: ['new wave', 'pop rock', 'power pop']
# The_Clash: ['punk rock', 'new wave', 'post-punk', 'reggae', 'experimental rock']
# The_Cranberries: ['alternative rock', 'indie rock', 'pop rock', 'jangle pop', 'post-punk', 'dream pop']
# The_Cult: ['hard rock', 'gothic rock', 'alternative rock', 'heavy metal', 'post-punk']
# The_Cure: ['gothic rock', 'post-punk', 'alternative rock', 'new wave']
# The_Dave_Clark_Five: ['rock and roll', 'beat', 'pop']
# The_Doobie_Brothers: ['rock', 'soft rock', 'pop', 'blue-eyed soul']
# The_Doors: ['psychedelic rock', 'blues rock', 'acid rock']
# The_Everly_Brothers: ['rock and roll', 'rockabilly', 'country rock', 'country']
# The_Fixx: ['new wave', 'pop rock', 'art rock', 'dance-rock']
# The_Flaming_Lips: ['neo-psychedelia', 'experimental rock', 'alternative rock', 'indie rock', 'psychedelic rock']
# The_Four_Seasons__band_: ['pop rock', 'pop', 'soul', 'doo-wop', 'rock and roll']
# The_Fray: ['alternative rock', 'pop rock', 'soft rock', 'christian rock']
# The_Go-Go_s: ['new wave', 'pop rock', 'power pop', 'post-punk', 'punk rock']
# The_Guess_Who: ['hard rock', 'psychedelic rock', 'blues rock', 'garage rock']
# The_Hives: ['garage rock revival', 'garage punk']
# The_Hollies: ['rock', 'pop']
# The_J__Geils_Band: ['rock', 'blues rock', 'new wave']
# The_Jam: ['mod revival', 'new wave', 'punk rock', 'power pop']
# The_Jesus_and_Mary_Chain: ['alternative rock', 'indie rock', 'noise pop', 'post-punk', 'shoegaze']
# The_Killers: ['alternative rock', 'indie rock', 'post-punk revival', 'new wave', 'heartland rock', 'pop rock']
# The_Kinks: ['rock', 'pop']
# The_Lovin__Spoonful: ['folk rock', 'pop', 'rock']
# The_Lumineers: ['indie folk', 'folk rock', 'americana']
# The_Mamas___the_Papas: ['pop', 'soul']
# The_Marshall_Tucker_Band: ['southern rock', 'country rock', 'progressive country', 'blues rock', 'jazz rock']
# The_Monkees: ['pop rock', 'rock', 'bubblegum', 'psychedelia']
# The_Moody_Blues: ['progressive rock', 'art rock', 'psychedelic rock', 'pop rock']
# The_Mothers_of_Invention: ['jazz rock', 'experimental rock', 'progressive rock', 'comedy rock', 'blues rock', 'avant-garde', 'doo-wop', 'art rock']
# The_Offspring: ['punk rock', 'skate punk', 'pop-punk', 'alternative rock']
# The_Outfield: ['pop rock', 'power pop', 'new wave']
# The_Police: ['new wave', 'reggae rock', 'pop rock']
# The_Presidents_of_the_United_States_of_America__band_: ['alternative rock', 'pop-punk', 'post-grunge']
# The_Pretenders: ['rock', 'pop rock', 'new wave', 'alternative rock']
# The_Pretty_Reckless: ['hard rock', 'alternative rock', 'post-grunge', 'blues rock']
# The_Rolling_Stones: ['rock', 'pop', 'blues']
# The_Script: ['pop rock', 'soft rock', 'indie rock']
# The_Smashing_Pumpkins: ['alternative rock']
# The_Smiths: ['indie pop', 'indie rock', 'jangle pop', 'alternative rock']
# The_Stone_Roses: ['madchester', 'indie rock', 'alternative rock', 'dance-rock', 'neo-psychedelia']
# The_Strokes: ['indie rock', 'garage rock revival', 'post-punk revival', 'new wave', 'synth-pop']
# The_Sweet: ['glam rock', 'hard rock', 'power pop', 'bubblegum']
# The_Tragically_Hip: ['alternative rock', 'roots rock', 'folk rock']
# The_Used: ['emo', 'screamo', 'post-hardcore', 'pop-punk', 'punk rock', 'alternative rock']
# The_Velvet_Underground: ['art rock', 'proto-punk', 'experimental rock']
# The_Verve: ['neo-psychedelia', 'alternative rock', 'britpop', 'shoegaze']
# The_White_Stripes: ['garage rock', 'blues rock', 'alternative rock', 'punk blues', 'indie rock']
# The_Who: ['rock', 'hard rock', 'power pop', 'proto-punk']
# The_Yardbirds: ['blues rock', 'psychedelic rock', 'rhythm and blues']
