# %%
import re
import os

def extract_genres_from_wikitext(wikitext_content):
    """
    Extracts genres from a Wikipedia infobox wikitext.
    """

    # It looks for 'genre =' followed by content, handling flatlist/list items,
    # and captures everything until the next field or end of infobox.
    genre_pattern = re.compile(
        r'\|\s*genre\s*=\s*(?:{{flatlist\||\s*\n\s*\*\s*)?(.*?)(?=\n\s*\||\n}})',
        re.DOTALL | re.IGNORECASE
    )

    # Regex to clean up the extracted genre string
    # - remove [[ and ]] for internal links, but keep the displayed text
    # - remove <ref> tags and their content
    # - remove {{flatlist| and *
    # - trim whitespace
    clean_genre_pattern = re.compile(r'\[\[(?:[^|\]]+\|)?([^\]]+)\]\]|<ref[^>]*>.*?<\/ref>|\{\{flatlist\||\*', re.DOTALL)


    match = genre_pattern.search(wikitext_content)
    if match:
        raw_genres_string = match.group(1).strip() # Access the first capturing group

        # Clean the string
        # This part will remove the wiki-markup for links and references.
        # Example: "[[Post-grunge]]<ref name=allmusic-bio/>" becomes "Post-grunge"
        cleaned_genres_string = clean_genre_pattern.sub(lambda m: m.group(1) if m.group(1) else '', raw_genres_string)

        # Split into individual genres, handle multiple lines/commas, and clean each
        # This regex will split by a newline followed by an asterisk (*), or just a comma, or just a newline.
        # This helps in splitting list-formatted genres.
        genres = [
            genre.strip()
            for genre in re.split(r'\n\*|\n|,', cleaned_genres_string)
            if genre.strip() # Remove any empty strings that might result from splitting
        ]
        return list(set(genres)) # Use set to get unique genres, then convert back to list
    return []

# %%
# Define the directory where your band data files are located
data_directory = "Bands"
band_genres = {}

# Iterate over all files in the specified directory
for filename in os.listdir(data_directory):
    file_path = os.path.join(data_directory, filename)
    band_name = os.path.splitext(filename)[0] # Get band name from filename

    try:
        with open(file_path, 'r', encoding='utf-8') as f:
            content = f.read()

            wikitext_content = content

            genres = extract_genres_from_wikitext(wikitext_content)
            band_genres[band_name] = genres
    except Exception as e:
        print(f"Error processing file {filename}: {e}")

# print number of bands that have infoboxes:
num_bands_with_infoboxes = sum(1 for genres in band_genres.values() if genres)
print(f"Number of bands with infoboxes: {num_bands_with_infoboxes} \n")

# Print the extracted genres for each band
for band, genres in band_genres.items():
    print(f"{band}: {genres}")
# Out:
# Number of bands with infoboxes: 475
#
# Funkadelic: ['{{hlist|Funk rock|psychedelic funk|acid rock|psychedelic rock}}']
# Slayer: ['<!--Do not change genre without discussing on the talk page first.-->Thrash metal']
# Ted_Nugent: ['Hard rock']
# T__Rex__band_: ['Glam rock', 'pop', '{{nowrap|psychedelic folk (early)}}']
# Great_White: ['Hard rock', 'glam metal']
# Days_of_the_New: ['Post-grunge', 'alternative metal', 'alternative rock']
# The_Dave_Clark_Five: ['{{Hlist|Rock and roll|beat|pop}}']
# Anthrax__American_band_: ['heavy metal', '{{nowrap|alternative metal}}', '<!--Do not change these genres without discussing on the talk page first.-->', 'Thrash metal', 'groove metal']
# Jimmy_Eat_World: ['power pop', 'Alternative rock', 'pop-punk', 'pop rock', 'emo']
# Flogging_Molly: ['folk punk', 'Celtic punk']
# Simple_Plan: ['power pop', 'Pop-punk', '<!-- All of these genres are sourced in the musical style section. Please cite a source for or discuss any additions -->', 'alternative rock', 'pop rock', 'emo']
# AC_DC: ['heavy metal', 'Hard rock', '<!--These genres are sourced under the genres section and have been agreed after several talk page discussions. Do not change without first obtaining consensus on the talk page.-->', 'blues rock', 'rock and roll']
# Joe_Walsh: ['{{hlist|Hard rock|blues rock|pop rock|progressive rock|country rock}}']
# Hoobastank: ['{{nowrap|nu metal}}', 'Alternative rock', 'funk metal (early)', 'ska punk (early)', 'post-grunge']
# Chicago__band_: ['jazz rock}}', 'pop rock', 'soft rock', 'Rock']
# Eddie_Money: ['{{Hlist|Rock|pop rock|hard rock}}']
# Roxy_Music: ['{{hlist|Art rock|glam rock|pop rock|sophisti-pop}}']
# Limp_Bizkit: ['Nu metal', 'rap rock', 'rap metal']
# Alice_Cooper__band_: ['{{hlist|Hard rock|glam rock|shock rock|psychedelic rock (early)}}<!--Genres must be sourced. Up to four genres is sufficient per the template guidance-->']
# Midnight_Oil: ['{{hlist|Alternative rock|hard rock|post-punk|new wave}}']
# Awolnation: ['electropop', 'Alternative rock', '{{nowrap|indie rock}}', 'electronic rock', '<!-- All of these genres are sourced in the musical style section. Do not change without a source!-->', 'pop rock', 'dance-rock']
# Marilyn_Manson: ['{{hlist|Industrial rock|industrial metal|gothic rock|alternative metal|shock rock}}']
# Thirty_Seconds_to_Mars: ['Alternative rock<!-- Please post in the talk page and seek consensus before changing or adding genres -->']
# Black_Stone_Cherry: ['{{hlist|Hard rock|Southern rock}}']
# The_Pretenders: ['{{hlist|Rock|pop rock|new wave|alternative rock}}']
# 10cc: ['{{hlist|Art rock|art pop|progressive pop|soft rock |pop rock}}']
# White_Zombie__band_: ['alternative metal', 'Groove metal', 'industrial metal', 'noise rock (early)']
# Eric_Clapton: ['blues', 'Rock']
# Pearl_Jam: ['<!--Please discuss on the talk page before adding or removing genres. Thank you.-->{{hlist|Alternative rock|grunge|hard rock}}']
# Billy_Talent: ['{{nowrap|post-hardcore}}', 'alternative rock', 'Punk rock', 'pop-punk']
# Starset: ['{{nowrap|hard rock}}', 'alternative metal', 'and many prominent sources define them as "Rock" and then proceed to describe all the other styles. We should do the same. Note the musical styles section covers a lot of ground.-->', 'Alternative rock', '<!--Please see "Musical style" section before making changes. We need to go by what sources say', 'progressive rock', 'electronic rock']
# Jack_White: ['{{hlist|Blues rock|garage rock revival|alternative rock|punk blues|folk|country|experimental rock}}']
# Queensrÿche: ['heavy metal', 'Progressive metal']
# Marilyn_Manson__band_: ['alternative metal', '{{nowrap|shock rock}}', 'gothic rock', 'industrial metal', 'Industrial rock']
# Alanis_Morissette: ['grunge', 'Alternative rock', 'electronica', 'indie pop', 'pop rock', 'trip hop', 'post-grunge']
# Korn: ['Nu metal', '<!-- main genres only -->', 'alternative metal']
# The_Marshall_Tucker_Band: ['{{Hlist|Southern rock|country rock|progressive country|blues rock|jazz rock}}']
# Steve_Vai: ['Instrumental rock', 'hard rock', 'heavy metal', 'progressive metal']
# George_Thorogood: ['rock and roll', 'hard rock', 'Blues rock<ref name="Music"/>', 'boogie rock']
# Peter_Frampton: ['Rock']
# Dire_Straits: ['Roots rock', 'blues rock', 'pub rock']
# Linkin_Park: ['alternative metal', 'nu metal', 'Alternative rock', '<!-- These genres are sourced in the "style and influences" section of the article text and have at least 3 sources each. -->', '{{nowrap|rap rock}}', 'electronic rock', 'pop rock']
# The_Moody_Blues: ['{{hlist|Progressive rock|art rock|psychedelic rock|pop rock}}']
# Black_Sabbath: ['Heavy metal<!--Before adding or changing genres', 'please seek consensus on the talk page first-->']
# Garbage__band_: ['{{nowrap|dance-rock}}', 'Alternative rock', 'electronic rock', 'trip hop', 'industrial rock']
# Our_Lady_Peace: ['Alternative rock', 'post-grunge']
# Bloodhound_Gang: ['rap rock', 'Alternative rock', 'new wave', 'pop-punk']
# John_Mayall: ['British blues', 'blues rock', 'jazz&nbsp;rock']
# The_Hollies: ['{{hlist|Rock|pop}}']
# Franz_Ferdinand__band_: ['<!-- All the genres are sourced in the article prose. -->', 'art rock', 'Indie rock', 'art punk', 'post-punk revival', '{{nowrap|dance-punk}}']
# Run-DMC: ['{{hlist|Hip-hop|rap rock}}']
# Steve_Winwood: ['rock', 'pop', 'R&B', 'Blue-eyed soul']
# Kid_Rock: ['{{nowrap|heavy metal}}', 'hip-hop', 'country', 'Rock']
# Small_Faces: ['progressive pop', 'psychedelia', 'beat', 'pop', 'proto-punk', 'Rock', 'R&B']
# Boys_Like_Girls: ['{{Flat list|', 'pop-punk', 'Pop rock', 'emo pop']
# Eagles__band_: ['<!-- These genres are backed by multiple sources under the section #Musical style -->{{hlist|Rock|country rock|soft rock|{{nowrap|folk rock}}}}']
# Cheap_Trick: ['hard rock', 'power pop', 'Rock']
# Ozzy_Osbourne: ['hard rock', 'Heavy metal']
# Cold_Chisel: ['Pub rock', 'hard rock', 'R&B', 'rock and roll']
# Chubby_Checker: ['Rock and roll']
# Tesla__band_: ['{{hlist|Hard rock|blues rock|glam metal}}']
# New_York_Dolls: ['{{hlist|Hard rock|proto-punk|{{nowrap|glam rock}}|glam punk}}']
# Elton_John: ['blues', 'Pop rock', 'glam rock', 'soft rock']
# Def_Leppard: ['power pop', '<!--These genres are sourced in the musical style section.-->', 'Hard rock', '{{nowrap|heavy metal (early)}}', 'glam metal', '{{nowrap|arena rock}}']
# The_Cure: ['post-punk', 'Gothic rock', 'please discuss it on the talkpage first -->', 'new wave <!-- The Cure is considered new wave', '{{nowrap|alternative rock}}']
# Ringo_Starr: ['{{hlist|Rock|pop}}']
# Charlie_Daniels: ['{{Hlist|Southern rock|country rock|progressive country|bluegrass}}']
# Joan_Jett: ['a discussion to reach consensus is needed first per: https://en.wikipedia.org/wiki/Template:Infobox_musical_artist#instrument--->', '{{hlist|Rock|hard rock|punk rock}}', '<!--Please do not add to this list without first discussing your proposal on the talk page. -->| instruments       = {{hlist|Vocals|guitar}}<!--- If you think an instrument should be listed or removed']
# Staind: ['Alternative metal', 'hard rock', '{{nowrap|nu metal}}', '{{nowrap|post-grunge}}']
# Status_Quo__band_: ['{{hlist|Rock|boogie rock|hard rock|psychedelia (early)}}']
# Snow_Patrol: ['indie rock', 'post-Britpop', 'power pop', 'Alternative rock']
# Talking_Heads: ['New wave', 'avant-funk', 'post-punk', 'art pop', 'worldbeat']
# Breaking_Benjamin: ['<!-- Please do not remove these genres. They are all sourced in the article.-->{{nowrap|alternative rock}}<!-- Please do not remove these genres. They are all sourced in the article.-->', 'alternative metal', 'Hard rock', '<!-- See Talk:Breaking Benjamin#July 11', '2015 -->', 'post-grunge']
# Dave_Matthews_Band: ['jam rock', 'Rock']
# The_Fray: ['{{hlist|Alternative rock|pop rock|soft rock|Christian rock (early)}}']
# Theory_of_a_Deadman: ['alternative metal', 'hard rock', 'pop rock', 'Post-grunge', '{{nowrap|alternative rock}}']
# Van_Halen: ['arena rock', 'heavy metal', 'Hard rock', 'pop rock', 'glam metal']
# Journey__band_: ['jazz rock (early)', 'progressive rock (early)', '<!-- Please discuss on the talk page before adding/removing genres. -->', 'hard rock', 'Arena rock', '{{nowrap|soft rock}}']
# Harry_Chapin: ['Folk rock', '{{flat list|', 'pop rock']
# Van_Morrison: ['folk', 'Celtic', 'blues', 'rock', 'Christian', 'country', 'Blue-eyed soul', 'jazz', 'gospel', 'R&B']
# Judas_Priest: ['Heavy metal']
# Jefferson_Starship: ['psychedelic rock', 'hard rock', 'progressive rock', 'Rock', 'soft rock']
# The_Smashing_Pumpkins: ['<!--PLEASE DO NOT ADD ANY MORE GENRES WITHOUT DISCUSSING IT ON THE TALK PAGE!--> Alternative rock']
# R_E_M_: ['folk rock', 'Alternative rock', 'college rock', 'jangle pop', 'post-punk', '<!--Genres are sourced in the "musical style" section-->']
# Harry_Nilsson: ['pop', 'Rock']
# Bob_Dylan: ['Folk', 'traditional pop', 'blues', 'rock', 'country', 'gospel']
# Jethro_Tull__band_: ['folk rock', '{{nowrap|hard rock}}', 'Progressive rock', 'blues rock']
# ZZ_Top: ['{{hlist|Blues rock|hard rock|boogie rock|Southern rock}}']
# Tool__band_: ['context', 'and weight', '<!--These are in alphabetical order and only suited as a rough overview. For sources', 'read the biography! -->{{hlist|Alternative metal|art rock|{{nowrap|post-metal}}|progressive metal|progressive rock}}']
# Highly_Suspect: ['grunge', 'garage rock', '{{nowrap|blues rock}}', 'Alternative rock', 'hard rock']
# Peter_Gabriel: ['{{hlist|Progressive rock|art rock|worldbeat|progressive soul}}<!-- All genres verified in #Artistry. Per Template:Infobox musical artist', 'aim for generality and broad genres -->']
# Tenacious_D: ['<!-- Before changing the genres', 'please discuss it on the talk page -->{{hlist|Comedy rock|acoustic rock|hard rock|heavy metal}}']
# John_Lennon: ['{{hlist|Rock|pop|experimental}}']
# Matchbox_Twenty: ['{{nowrap|pop rock}}', 'Alternative rock', 'post-grunge']
# Sex_Pistols: ['Punk rock']
# Avenged_Sevenfold: ['Heavy metal', '{{nowrap|alternative metal}}', 'hard rock', '<!--Genres are sourced in the prose; five well-sourced genres is plenty-->', 'progressive metal', '{{nowrap|metalcore (early)}}']
# Yes__band_: ['art rock', 'pop rock', 'Progressive rock', 'symphonic rock']
# Adam_Ant: ['alternative rock', 'post-punk', 'New wave', 'dance-rock']
# Bullet_for_My_Valentine: ['{{nowrap|heavy metal}}', '<!--Only include genres with at least 2 sources.-->', 'thrash metal', 'hard rock', 'Melodic metalcore']
# Bee_Gees: ['disco', 'Pop', 'rock', 'soul', 'soft rock']
# Mudvayne: ['<!--Only include genres with at least 3 sources.-->', '{{nowrap|nu metal}}', '{{nowrap|Alternative metal}}', 'hard rock', 'progressive metal']
# Deftones: ['and consensus was to add these because they had the strongest support. Consensus as of 27 January 2025. --->', 'art rock', 'Alternative metal', '<!---DO NOT ALTER. There are so many genres that we had to narrow it down', 'shoegaze', '{{nowrap|nu metal (early)}}']
# Manfred_Mann_Chapter_Three: ['Jazz rock']
# Donovan: ['{{hlist|Folk|pop|psychedelia|rock}}']
# The_Fixx: ['{{hlist|New wave|pop rock|art rock|dance-rock}}']
# The_Big_Bopper: ['Rock and roll', 'country', 'rockabilly']
# Gary_Glitter: ['{{hlist|Glam rock|rock and roll|pop rock|hard rock|disco}}']
# Halestorm: ['Hard rock', 'heavy metal', 'alternative metal', '{{nowrap|post-grunge}}']
# Tracy_Chapman: ['{{hlist|Folk|blues rock|pop|soul}}']
# Dashboard_Confessional: ['acoustic rock', 'alternative rock', '{{nowrap|indie rock}}', 'Emo']
# Grateful_Dead: ['<!--PLEASE SEE TALK PAGE BEFORE ADDING ANY GENRES HERE-->Rock']
# The_Who: ['{{nowrap|power pop}}', 'hard rock', 'proto-punk', 'Rock', '<!-- PLEASE DO NOT change this without discussion on the talk page otherwise your edit may be reverted -->']
# Linda_Ronstadt: ['{{hlist|Country|rock|pop}}']
# Paul_McCartney_and_Wings: ['Soft rock']
# Bad_Company: ['Hard rock', 'blues rock']
# Imagine_Dragons: ['Pop rock', 'electropop', 'pop', 'alternative rock', '<!-- All of these genres are sourced in the musical style section. Do not change without a source!-->', '{{nowrap|arena rock}}', '{{nowrap|indie pop}}']
# Counting_Crows: ['roots rock', 'Alternative rock', 'pop rock']
# Smokie__band_: ['Pop rock', 'glam rock', 'soft rock']
# The_Outfield: ['new wave', 'Pop rock']
# FireHouse: ['Glam metal', 'hard rock']
# Bruce_Springsteen: ['folk', '{{flat list|', 'pop rock', 'Rock', 'heartland rock']
# Toto__band_: ['jazz fusion', 'hard rock', 'progressive rock', 'pop rock', 'Arena rock']
# Coldplay: ['pop', 'Alternative rock', 'pop rock', '{{Nowrap|post-Britpop}}']
# Manfred_Mann__musician_: ['Beat', 'R&B<ref name=Eder>{{cite web |url=https://www.allmusic.com/artist/manfred-mann-mn0000674662 |title=Manfred Mann Biography by Bruce Eder', 'blues rock']
# X_Ambassadors: ['{{hlist|Alternative rock|indie rock|indie pop|pop rock|alternative pop}}']
# Steve_Miller_Band: ['{{Hlist|Blues rock|pop rock}}']
# Alice_Cooper: ['<!-- PLEASE DO NOT change this without discussion on the talk page otherwise your edit may be reverted -->{{hlist|Hard rock|shock rock|{{nowrap|glam rock}}|heavy metal}}']
# Good_Charlotte: ['emo', 'alternative rock', 'pop rock', 'Pop-punk']
# Nine_Inch_Nails: ["the genres you're adding have citations.--->", 'industrial', '<!---There are several sourced genres. Only include genres with the most sources in the genre field', 'industrial metal', 'electronic rock', 'ambient', 'see the Artistry section. Do NOT add any unsourced genres. Make sure when you add genres', '{{nowrap|alternative rock}}', 'Industrial rock']
# Incubus__band_: ['funk metal (early)', 'alternative metal', 'Alternative rock', 'nu metal (early)']
# Tom_Petty_and_the_Heartbreakers: ['<!--Do not change this without forming a consensus.-->', '{{nowrap|Southern rock}}', 'heartland rock', 'Rock']
# The_Offspring: ['<!-- These genres are sourced in the "Style and influences" section.-->', 'alternative rock', 'Punk rock', '{{nowrap|pop-punk}}', 'skate punk']
# Papa_Roach: ['alternative metal', '<!---All genres are sourced in the body. Now the genre field can look better. --->', 'nu metal', 'Alternative rock', 'rap metal', 'hard rock']
# Extreme__band_: ['Hard rock', '{{nowrap|glam metal}}', 'funk metal']
# Herman_s_Hermits: ['{{hlist|Beat|pop rock|bubblegum}}']
# Santana__band_: ['{{hlist|Latin rock|blues rock|psychedelic rock|acid rock|Chicano rock|jazz fusion|yacht rock}}']
# Mötley_Crüe: ['hard rock}}<!--- PLEASE DO NOT CHANGE OR ADD GENRES WITHOUT CONSENSUS ON THE TALK PAGE.--->', 'Heavy metal', 'glam metal']
# Robert_Plant: ['{{hlist|Rock|blues|folk|country|hard rock|heavy metal}}']
# Evanescence: ['<!-- Do not change the genres without consensus. The genres are the most heavily sourced in the article and were chosen in the most recent consensus on the talk page.-->', 'gothic metal', 'Alternative metal', 'nu metal (early)', 'symphonic metal', 'gothic rock', 'hard rock', 'industrial rock']
# The_Presidents_of_the_United_States_of_America__band_: ['<!-- See musical style section for genre sources and breakdown -->', 'pop-punk', 'Alternative rock', 'post-grunge']
# Florence_and_the_Machine: ['{{hlist|Indie rock|indie pop|chamber pop|baroque pop|art pop|art rock|neo soul|folk}}']
# Aerosmith: ['Hard rock', 'heavy metal', 'blues rock']
# Catfish_and_the_Bottlemen: ['indie rock', 'post-punk revival', 'Alternative rock']
# Disturbed__band_: ['{{nowrap|hard rock}}', 'Heavy metal', 'alternative metal', 'nu metal (early)']
# Finger_Eleven: ['hard rock', '{{nowrap|nu metal}}', 'alternative metal', 'Alternative rock']
# Ten_Years_After: ['Blues rock']
# Oasis__band_: ['{{Hlist|Rock|Britpop}}']
# Traveling_Wilburys: ['Rock']
# Shinedown: ['<!-- These genres are sourced in the musical style section. -->', 'alternative metal', 'Hard rock', 'alternative rock', '{{nowrap|pop rock}}', '{{nowrap|post-grunge}}']
# The_Boxtones: ['Rock']
# Iggy_Pop: ['{{hlist|Rock|punk rock|proto-punk|hard rock|garage rock}}']
# Uriah_Heep__band_: ['Hard rock', 'heavy metal', 'progressive rock']
# Crowded_House: ['{{hlist|Pop rock|jangle pop|alternative rock}}']
# Cake__band_: ['{{hlist|Alternative rock|country|indie rock|funk rock}}']
# The_Doobie_Brothers: ['<!-- Do not add unsupported genres -->{{hlist|Rock|soft rock|pop|blue-eyed&nbsp;soul}}']
# Foals__band_: ['art rock', 'Indie rock', 'alternative rock', 'dance-punk', '{{nowrap|math rock}}']
# Mike_and_the_Mechanics: ['pop rock', 'Rock']
# John_Mellencamp: ['folk rock', 'roots rock', '<!-- All of these genres are sourced in the musical style section. Do not change without a source!-->', 'Heartland rock']
# Whitesnake: ['Hard rock', 'blues rock', 'glam metal']
# Queen__band_: ['pop<!-- This is a summary. Please do not attempt to list every single genre of every single track -->', 'Rock']
# The_Allman_Brothers_Band: ['{{hlist|Southern rock|blues rock|{{nowrap|jazz rock}}|jam band}}']
# X__American_band_: ['{{hlist|Punk rock|alternative rock}}']
# Silverchair: ['grunge', '{{nowrap|art rock}}', 'Alternative rock', 'remove or change genres without discussing on the talk page first.-->', '<!--Do not add', 'post-grunge']
# Montgomery_Gentry: ['{{hlist|Country|Southern rock|country rock}}']
# Tommy_James_and_the_Shondells: ['please! -->', '{{hlist|Rock|bubblegum}}<!-- Only genres reliably sourced in article']
# Simon___Garfunkel: []
# Death_Cab_for_Cutie: ['Indie rock', 'emo (early)', 'alternative rock', 'indie pop']
# Metallica: ['Heavy metal', 'thrash metal', 'hard rock', 'remove or change genres without discussing on the talk page first.-->', '<!--Do not add', '{{nowrap|speed metal}}']
# Sublime__band_: ['{{hlist|Ska punk|reggae rock}}']
# Gene_Vincent: ['rock and roll', 'country', 'Rockabilly', '{{flat list|']
# Ambrosia__band_: ['blue-eyed soul}}', 'Progressive rock', 'jazz fusion', 'soft rock']
# Fall_Out_Boy: ['Pop-punk', 'pop rock', "<!-- All genres are sourced on the 'Musical style' section -->", 'emo', '{{nowrap|alternative rock}}']
# Echo___the_Bunnymen: []
# Seether: ['nu metal (early)', '{{nowrap|alternative metal}}', 'hard rock', 'alternative rock', 'Post-grunge']
# Saliva__band_: ['Nu metal', 'hard rock<ref name="AMG" />', 'rap metal', 'post-grunge']
# The_Pretty_Reckless: ['Hard rock', 'alternative rock', '{{nowrap|post-grunge}}', 'blues rock']
# The_All-American_Rejects: ['{{nowrap|Pop-punk}}', 'power pop', 'emo pop<ref name=AllMusicBio/>', 'pop rock']
# Badfinger: ['power pop', 'Rock']
# Accept__band_: ['Heavy metal']
# The_Cardigans: ['indie rock', 'Alternative rock', 'indie pop', 'pop rock']
# George_Harrison: ['{{hlist|Rock|pop|Indian classical}}']
# Huey_Lewis_and_the_News: ['{{hlist|Rock|new wave|rhythm & blues}}']
# Thin_Lizzy: ['Hard rock', 'folk rock (early)', 'heavy metal', 'blues rock']
# Rise_Against: ['Punk rock', 'melodic hardcore']
# Travis__band_: ['alternative rock', 'Post-Britpop', 'pop rock']
# Steely_Dan: ['jazz fusion}}', 'pop', 'yacht rock', 'Jazz rock', '{{nowrap|soft rock}}']
# Edgar_Winter: ['{{hlist|Southern rock|pop|jazz fusion|blues rock|blue-eyed soul|boogie rock}}']
# Ramones: ['see talk page -->', 'pop-punk', 'Punk rock', 'do not remove these genres as they are sourced. Removed "power Pop"', '<!-- These genres are sourced in the article text. Do not add genres without a source or discussion. Also']
# Lacuna_Coil: ['alternative metal', 'Gothic metal']
# Gin_Blossoms: ['<!-- Sourced in musical style section -->', 'power pop', 'country rock', 'Alternative rock', 'jangle pop', 'post-grunge']
# Pantera: ['<!-- Sourced in the section #Musical style and influences -->', 'thrash metal', 'Groove metal', '{{nowrap|glam metal (early)}}']
# Everlast: ['folk rock', 'Hip hop', 'blues']
# Kaleo__band_: ['Blues rock', 'alternative rock', 'indie folk']
# U2: ['post-punk', 'alternative rock', 'pop rock', 'Rock']
# Dan_Fogelberg: ['{{Hlist|Rock|country|folk|folk rock|soft rock|pop rock|pop}}']
# Pat_Benatar: ['{{hlist']
# Bread__band_: ['Soft rock']
# Boston__band_: ['Hard rock', 'arena rock']
# Parliament__band_: ['{{hlist|Funk|R&B|psychedelic soul}}']
# Sting__musician_: ['{{hlist|Pop|new wave|soft rock}}']
# Buddy_Holly: ['{{hlist|Rock and roll|rockabilly|pop}}']
# Slade: ['{{hlist|Glam rock}} hard rock']
# Arcade_Fire: ['<!--Do not add unsourced genres-->{{hlist|Indie rock|art rock|dance-rock|baroque pop}}']
# Stevie_Ray_Vaughan: ['Texas blues', '{{flat list|', 'blues rock', 'rock and roll', 'electric blues']
# Kings_of_Leon: ['no unnecessary capital letters except for proper words (e.g. Southern). ANY UNNECESSARY CAPITAL LETTERS WILL BE REVERTED! -->|indie rock|garage rock revival}}', '{{hlist|Alternative rock|Southern rock<!-- Per WP:MOSCAPS']
# Motörhead: ['{{nowrap|hard rock}}', 'Heavy metal', 'speed metal}}', '<!--DO NOT CHANGE THESE GENRES WITHOUT FIRST OBTAINING CONSENSUS-->']
# Little_Richard: ['{{hlist|Rock and roll|rhythm and blues|gospel|soul}}']
# Scorpions__band_: ['Hard rock', 'heavy metal', '<!-- main genres only. its not relevant that they had minor hair metal influences 40 years ago -->']
# Interpol__band_: ['{{hlist|Indie rock|post-punk revival}}']
# Rob_Zombie: ['alternative metal', 'Industrial metal', 'nu metal', 'hard rock', 'shock rock', 'groove metal']
# The_Beach_Boys: ['psychedelia', 'pop', '<!--PLEASE DO NOT CHANGE GENRES WITHOUT TALK PAGE CONSENSUS-->', 'Rock', 'surf']
# Jefferson_Airplane: ['folk rock', 'acid rock', 'Psychedelic rock']
# The_Bangles: ['{{hlist|Pop rock|power pop|new wave|paisley underground<ref name="AllMusic" />}}']
# System_of_a_Down: ['Alternative metal', 'nu metal', '<!-- only main genres -->', 'hard rock', 'progressive metal']
# Sixto_Rodriguez: ['{{hlist|Folk rock|psychedelic folk|psychedelic rock}}']
# Michael_Martin_Murphey: ['bluegrass', 'western/cowboy music', 'Progressive country']
# Europe__band_: ['hard rock', 'Arena rock', 'blues rock', 'glam metal']
# Starship__band_: ['arena rock', 'pop rock<ref name="AllMusicStarshipBio"/>', 'Rock']
# Blue_October: ['{{hlist|Alternative rock|art rock|post-grunge|new wave|synth-pop|shoegaze}}']
# Traffic__band_: ['{{hlist|Progressive rock||psychedelic rock|jazz rock|folk rock|psychedelic pop (early)']
# The_Cult: ['<!-- sourced under Musical style -->{{hlist|Hard rock|gothic rock|alternative rock|heavy metal|post-punk (early)}}']
# The_Flaming_Lips: ['psychedelic rock', 'Neo-psychedelia', 'alternative rock', 'indie rock', 'experimental rock']
# Crash_Test_Dummies: ['folk rock', 'Alternative rock']
# The_Lumineers: ['{{hlist|Indie folk|folk rock|Americana}}']
# Twisted_Sister: ['<!--Only include genres with at least 2 sources.-->', 'Heavy metal', 'hard rock', 'shock rock', 'glam metal']
# Slipknot__band_: ['Nu metal', '{{nowrap|groove metal}}', 'alternative metal', "<!--All genres are sourced. Please do NOT edit anything within this section without first establishing consensus on the talk page using reliable sources. Slipknot's genre has already been firmly established. -->"]
# Audioslave: ['alternative metal', "<!-- All genres are sourced in the 'Musical style' section-->", 'Hard rock', '{{nowrap|post-grunge}}', '{{nowrap|alternative rock}}']
# The_Kinks: ['{{hlist|Rock|pop}}']
# P_O_D_: ['Nu metal', 'hardcore punk (early)', 'alternative metal', '{{nowrap|rap rock}}']
# Alter_Bridge: ['heavy metal', 'alternative metal', 'Hard rock', 'alternative rock', 'progressive metal', 'post-grunge']
# Paramore: ['power pop', '<!--Please do not remove cited genres or add genres without discussion. No need to cite sources in the infobox', 'as these are noted in the Musical style and influences section.-->', 'Pop-punk', 'pop rock', 'emo', '{{nowrap|alternative rock}}', '{{nowrap|new wave}}']
# Three_Dog_Night: ['{{hlist|Pop rock |soft rock|roots rock|funk rock}}']
# Kenny_Loggins: ['folk rock', '{{flat list|', 'pop', 'soul', 'Rock', 'soft rock}}', 'R&B']
# Ian_Dury: ['{{hlist|New wave|punk rock|post-punk|funk|disco|pub rock}}']
# Killswitch_Engage: ['Melodic metalcore']
# The_Zombies: ['{{hlist|']
# Guns_N__Roses: ['heavy metal', 'other genres discussed in article-->', 'hard rock and heavy metal to be only genres listed', 'Hard rock', '<!-- Per discussion on talk page']
# The_Guess_Who: ['<!-- genres listed here are sourced in the article text -->{{hlist|Hard rock|psychedelic rock|blues rock|garage rock}}']
# Soundgarden: ['heavy metal', 'alternative metal', 'remove or change genres without discussing on the talk page first. -->', 'Grunge', '<!-- Do not add', '{{nowrap|alternative rock}}']
# Hole__band_: ['{{hlist|Alternative rock|grunge{{sfn|Kallen|2012|p=78}}|punk rock{{sfn|Hogg|2001|p=42}}|noise rock{{sfn|Anderson|2007|p=213}}|power pop<ref name="flipside" />}}']
# Icehouse__band_: ['{{hlist|Rock|new wave|synth-pop}}']
# Twenty_One_Pilots: ['alternative hip-hop', 'pop rap', 'not all must be listed here. -->', 'electropop', 'Alternative rock', 'pop rock', '<!-- All genres should be sourced in the "Musical style and influences" section of the article! The duo encompasses a large variety', '{{nowrap|indie pop}}']
# Bring_Me_the_Horizon: ['alternative metal', 'post-hardcore', 'and have consensus in the talk page. -->', 'Metalcore', '{{nowrap|deathcore (early)}}', 'alternative rock', '<!-- These genres are sourced in the "style and influences" section of the article text', '{{nowrap|pop rock}}', 'electronic rock']
# Skillet__band_: ['{{nowrap|hard rock}}', 'alternative metal', 'nu metal', 'Christian rock', 'alternative rock', 'post-grunge']
# Mitch_Ryder: ['{{hlist|Rock and roll|rhythm and blues|blue-eyed soul|frat rock|hard rock}}']
# The_Sweet: ['{{hlist|Glam rock|hard rock|power pop|bubblegum (early)}}']
# Chris_Rea: ['Pop rock', 'electric blues', 'blues rock', 'soft rock']
# James_Blunt: ['{{hlist|Pop rock|folk rock|folk pop|soft rock}}']
# Stone_Temple_Pilots: ['grunge', 'psychedelic rock', '{{nowrap|hard rock}}', 'alternative metal', 'Alternative rock']
# Sublime_with_Rome: ['dub', 'hip hop', 'Reggae rock', 'ska punk', 'punk rock', 'alternative rock']
# Chuck_Berry: ['Rock and roll', 'rhythm and blues}}']
# Morrissey: ['{{hlist|', 'Alternative rock|indie pop|indie rock|jangle pop}}']
# Duran_Duran: ['synth-pop', 'Pop rock', 'new wave', 'dance-rock']
# Bryan_Adams: ['{{hlist|Rock|pop rock|soft rock|arena rock|heartland rock}}']
# Sum_41: ['alternative metal', 'melodic hardcore', 'Pop-punk', 'punk rock', 'alternative rock', 'skate punk']
# Collective_Soul: ['hard rock', 'Alternative rock', 'post-grunge']
# Hall___Oates: []
# Manfred_Mann: ['Blues rock', 'psychedelia<ref name=Petridis/>', 'pop', 'R&B']
# The_Police: ['reggae rock', 'New wave', 'pop rock']
# Coheed_and_Cambria: ['<!--- All of these genres are cited below. --->', 'Progressive rock', 'alternative rock', '{{nowrap|post-hardcore}}', 'progressive metal', 'as recommended by Template:Infobox musical artist#genre. Progressive metal', 'emo', "<!-- These five genres summarize Coheed and Cambria's general musical focus", 'alternative metal and other subgenres are better covered in the text than included here. -->']
# The_Killers: ['new wave', 'Alternative rock', 'pop rock', 'indie rock', '{{nowrap|post-punk revival}}', 'heartland rock']
# John_Mayer: ['blues', 'pop', 'Rock']
# April_Wine: ['Hard rock']
# Sepultura: ['alternative metal', '{{nowrap|death metal}}', 'thrash metal', '<!--- All genres are sourced with citations. Please DO NOT add', 'Groove metal', 'change or remove any genres without discussing on the talk page first. --->']
# Iron_Maiden: ['Heavy metal']
# Survivor__band_: ['{{hlist|Rock|arena rock|hard rock}}']
# Jackson_Browne: ['country rock', '{{Flat list|', 'folk rock', 'pop rock', 'soft rock', 'Rock']
# No_Doubt: ['Ska punk', 'pop-punk', 'alternative rock', 'pop rock', 'reggae', '{{nowrap|new wave}}']
# Electric_Light_Orchestra: ['{{hlist|']
# Green_Day: ['{{nowrap|power pop}}', "<!-- DO ''not'' CHANGE WITHOUT A TALK PAGE DISCUSSION -->", 'pop-punk', 'Punk rock', '{{nowrap|skate punk}}', '{{nowrap|alternative rock}}']
# Jimi_Hendrix: ['{{hlist|Rock|psychedelia|blues|R&B}}<!--Please do not add to this list without first discussing your proposal on the talk page.-->']
# Volbeat: ['Heavy metal', '{{nowrap|rock and roll}}', 'rockabilly', 'hard rock', '{{nowrap|groove metal}}', 'psychobilly']
# Blues_Traveler: ['jam band', '<!-- Only 4 genres in infobox. -->', 'folk rock', 'Blues rock', 'alternative rock', 'southern rock']
# Trivium__band_: ['<!--Only include genres with at least 3 sources.-->', 'metalcore', 'Heavy metal', 'thrash metal', 'progressive metal']
# The_Byrds: ['country rock', 'raga rock', 'folk rock', 'psychedelia', '{{flat list|', 'pop', 'Rock', 'jangle pop}}']
# Vampire_Weekend: ['Indie rock', '{{nowrap|baroque pop}}', '{{nowrap|art pop}}', 'indie pop', 'worldbeat']
# Red_Hot_Chili_Peppers: ['alternative rock', 'Funk rock', '{{nowrap|funk metal}}', 'rap rock']
# The_Four_Seasons__band_: ['Pop rock', 'soul', 'pop', 'doo-wop']
# Fun__band_: ['indie rock', '{{nowrap|baroque pop}}', 'Indie pop', 'pop rock']
# Bay_City_Rollers: ['{{Hlist|Pop|glam rock|pop rock}}']
# Fuel__band_: ['hard rock', 'alternative metal', 'Alternative rock', 'post-grunge']
# Avril_Lavigne: ['pop', 'alternative rock', 'pop rock', 'Pop-punk']
# The_Cars: ['power pop', 'New wave', 'pop rock']
# Elvis_Presley: ['Rock and roll', 'rockabilly', 'blues', 'pop', 'country', 'soul', 'gospel', 'R&B']
# Air_Supply: ['{{hlist|Soft rock|pop rock|pop|adult contemporary|middle-of-the-road}}']
# Lifehouse__band_: ['{{hlist|Alternative rock||post-grunge|pop rock}}']
# The_Yardbirds: ['Blues rock', 'psychedelic rock', 'R&B']
# Van_Zant__band_: []
# Parliament-Funkadelic: ['Funk', 'psychedelic funk', '{{flat list|', 'funk rock', 'progressive soul', 'acid rock']
# Pixies__band_: ['{{hlist|Alternative rock|indie rock|noise pop|punk rock|surf rock}}']
# John_Fogerty: ['Roots rock', 'rock and roll', '{{nowrap|heartland rock}}', 'country rock']
# Filter__band_: ['{{nowrap|hard rock}}', 'alternative metal', 'alternative rock', 'industrial metal', '<!-- Genres sourced in the musical style section; included genres with 3 or more sources -->', 'post-grunge', 'Industrial rock']
# Chris_Cornell: ['{{hlist|Alternative metal|heavy metal|grunge|alternative rock|hard rock}}']
# Grand_Funk_Railroad: ['Hard rock Arena rock']
# 10_Years__band_: ['{{hlist|Alternative metal|progressive metal|post-grunge|nu&nbsp;metal}}']
# Beck: ['electronic', 'folk rock', 'psychedelia', 'Alternative rock', 'alt-country', 'lo-fi (early)']
# Live__band_: ['hard rock', 'Alternative rock', 'post-grunge']
# Arctic_Monkeys: ['psychedelic rock', '<!-- These genres are sourced in the "style and influences" section of the article text. -->', 'lounge pop', 'garage rock', 'Indie rock', 'alternative rock', '{{nowrap|post-punk revival}}']
# Smash_Mouth: ['power pop', 'Alternative rock', 'pop rock', 'ska punk']
# Neil_Young: ['{{hlist|Rock|folk rock|country rock}}']
# Hinder: ['Post-grunge', 'hard rock']
# Jerry_Lee_Lewis: ['Rock and roll', 'rockabilly', 'blues', '{{nowrap|boogie-woogie}}', 'country', '{{nowrap|honky-tonk}}', 'gospel']
# Jet__Australian_band_: []
# Megadeth: ['<!--Do not change these genres without discussing on the talk page first.-->{{hlist|Thrash metal{{sfn|Phillips|Cogan|2009|pp=156-157}}|speed metal{{sfn|Phillips|Cogan|2009|pp=156-157}}|heavy metal{{sfn|Phillips|Cogan|2009|pp=156-157}}}}']
# Muse__band_: ['space rock', 'art rock', 'Alternative rock', 'hard rock', 'progressive rock', 'electronic rock']
# Ritchie_Valens: ['Rock and roll', 'Chicano rock']
# Dio__band_: ['Heavy metal']
# Supertramp: ['{{flat list|', 'pop', 'progressive rock', 'Progressive pop', 'soft rock']
# Drowning_Pool: ['{{nowrap|hard rock}}', 'Alternative metal', '<!--All of these genres are sourced in the musical style section. Do not change without a source! Do not remove genres without an explanation-->', 'nu metal', 'post-grunge']
# Manfred_Mann_s_Earth_Band: ['{{hlist|Progressive rock|hard rock|jazz rock}}']
# Billy_Joel: ['{{nowrap|pop rock}}<ref name="concert archives"/>', 'soft rock', 'Rock']
# The_J__Geils_Band: ['{{hlist|Rock|blues rock (early)|new wave (later)}}']
# Five_for_Fighting: ['{{hlist|Soft rock|heartland rock|alternative rock|pop rock|Americana|{{nowrap|adult contemporary}}}}']
# The_Monkees: ['Pop rock', '<!--Aim for generality&nbsp;— see https://en.wikipedia.org/wiki/Template:Infobox_musical_artist#Genre-->', 'psychedelia', 'rock', 'bubblegum']
# Steppenwolf__band_: ['{{hlist|Psychedelic rock|blues rock|acid rock|hard rock|heavy metal||garage rock}}']
# Fleetwood_Mac: ['Pop rock', 'art pop', 'blues rock', 'soft rock']
# Foreigner__band_: ['{{hlist|Hard rock|soft rock|arena rock}}']
# UB40: ['{{hlist|Reggae|dub}}']
# Kaiser_Chiefs: ['<ref name=AllMusic/> pop rock', 'power pop', 'Indie rock', 'art punk', 'alternative rock', 'pop punk', 'post-punk revival']
# Elvis_Costello: ['new wave', 'power pop', 'pub rock', 'punk rock', 'pop', 'Rock']
# The_Go-Go_s: ['power pop', 'New wave', 'punk rock (early)', 'post-punk', 'pop rock']
# Dropkick_Murphys: ['Celtic punk', 'oi!', 'folk punk', '{{nowrap|street punk}}', '{{nowrap|hardcore punk}}']
# Goo_Goo_Dolls: ['{{hlist|', 'Alternative rock|pop rock|post-grunge|punk rock <small>(early)</small><ref name="allmusic-bio"/>}}']
# Golden_Earring: ['{{hlist|Hard rock|blues rock|jazz rock|psychedelic rock|garage rock}}<!-- only genres sourced in article', 'please -->']
# The_Verve: ['Neo-psychedelia', 'shoegaze (early)', 'alternative rock', 'Britpop']
# Sam_Fender: ['<!-- Genres listed here are sourced in the article text -->', 'pop rock', 'Rock', 'indie rock', 'heartland rock']
# Foo_Fighters: ['{{nowrap|hard rock}}', '<!-- sourced below -->', 'Alternative rock', 'post-grunge']
# Fats_Domino: ['{{hlist|Rock and roll|New Orleans R&B|boogie-woogie|blues}}']
# Keane__band_: ['post-Britpop', 'rock', 'Alternative rock', 'soft rock']
# Men_at_Work: ['{{hlist|New wave|pop rock|reggae rock}}']
# England_Dan___John_Ford_Coley: []
# Jane_s_Addiction: ['psychedelic rock', 'alternative metal', 'Alternative rock', 'funk metal']
# Velvet_Revolver: ['Hard rock', 'alternative metal']
# ABBA: ['disco', 'Pop', 'Europop', 'pop rock', '}}']
# Bush__British_band_: ['grunge', '{{nowrap|hard rock}}', '<!--- PLEASE READ! All genres have citations. Please do NOT remove any of these genres. --->', 'alternative rock', 'Post-grunge']
# Three_Days_Grace: ['alternative metal', '{{nowrap|nu metal}}', 'hard rock', 'Post-grunge', '{{nowrap|alternative rock}}']
# Kansas__band_: ['hard rock', 'art rock', 'Progressive rock', '{{nowrap|arena rock}}']
# The_Jam: ['Mod revival', 'new wave', 'power pop', 'punk rock']
# Joy_Division: ['punk rock', 'new wave', 'Post-punk', 'gothic rock']
# The_Velvet_Underground: ['{{hlist|Art rock|{{nowrap|proto-punk}}|experimental rock}}']
# The_Hives: ['{{hlist|Garage rock revival|garage punk}}']
# Jeff_Buckley: ['{{Flat list|', 'Alternative rock', 'folk-rock', 'blues']
# Greta_Van_Fleet: ['Hard rock', 'progressive rock', 'blues rock']
# Blue_Öyster_Cult: ['psychedelic rock', 'heavy metal', 'occult rock', 'Hard rock', 'progressive rock', 'acid rock']
# Sonic_Youth: ['{{nowrap|post-punk}}', 'Noise rock', 'alternative rock', 'they must be cited in-article by reputable sources. -->', '<!-- In order to add genres to an infobox', 'indie rock', 'no wave (early)', 'experimental rock']
# Beastie_Boys: ['Hip-hop', 'rap rock', 'alternative hip-hop', 'hardcore punk (early)']
# Radiohead: ['alternative rock<!--Genres are sourced in the Style and songwriting section of the article; do not add without consulting talk page with sourced information.-->', 'electronica', 'experimental rock', 'Art rock']
# Blink-182: ['Pop-punk<!--See Musical style and influences section for sourced genres.-->', 'alternative rock', 'punk rock', 'skate punk']
# Asia__band_: ['{{hlist|Progressive rock|AOR|pop rock}}']
# Shakin__Stevens: ['Rockabilly', 'rock and roll}}']
# The_Jesus_and_Mary_Chain: ['noise pop', 'Alternative rock', 'post-punk', 'indie rock', 'shoegaze']
# Bo_Diddley: ['{{Hlist|Rock and roll|blues<ref name=Erlewine/>|psychedelic funk<ref name=Erlewine/>}}']
# Styx__band_: ['arena rock', 'art rock', 'Progressive rock', 'pop rock']
# Faith_No_More: ['<!-- All genres are sourced in the article. Please do not change. -->', 'Alternative metal', 'alternative rock', 'funk metal', 'experimental rock']
# Stevie_Nicks: ['{{hlist|Rock|pop|folk}}']
# Billy_Squier: ['Hard rock', 'power pop', 'pop rock', 'arena rock']
# Queens_of_the_Stone_Age: ['DO NOT CHANGE OR ADD TO WITHOUT DISCUSSING FIRST -->', '{{hlist|Alternative rock|stoner rock|desert rock|{{nowrap|hard rock}}|alternative metal}}<!-- THESE GENRES WERE DECIDED ON VIA CONSENSUS ON THE ARTICLE TALK PAGE']
# The_Everly_Brothers: ['country rock', 'Rock and roll', 'country', 'rockabilly']
# David_Bowie: ['electronic', 'pop', 'glam rock', 'Art rock']
# Paul_McCartney: ['classical', 'pop', 'electronic', 'Rock']
# Godsmack: ['Alternative metal', 'nu metal (early)', '<!--Please only add genres with at least four sources -->', 'hard rock', '{{nowrap|post-grunge}}']
# Lamb_of_God__band_: ['metalcore', 'thrash metal', '{{nowrap|death metal (early)}}', 'Groove metal', '<!---There are many sourced genres. These are the most well-sourced genres and these genres represent what Lamb of God\'s overall music style is. Do not remove them nor add genres that are only sourced for Burn the Priest albums. All genres are sourced in the "Musical style and influences" section.--->']
# Tom_Petty: ['country rock', '{{nowrap|roots rock}}', 'Southern rock', '<!---Do not change this list without reaching a consensus for it.--->', 'Rock', 'heartland rock']
# Kiss__band_: ['heavy metal', 'Hard rock', '<!--Note: Please do not change/add genres without first discussing it on the talk page', 'thank you!-->', 'glam rock', 'shock rock']
# The_Animals: ['<!-- Do not add unsourced genres -->{{hlist|Blues rock']
# Skid_Row__American_band_: ['hard rock', 'Heavy metal', 'glam metal']
# The_Band: ['{{hlist|Roots rock|Americana|folk rock|country rock}}']
# The_Cranberries: ['Alternative rock', 'jangle pop', 'post-punk', 'pop rock', 'indie rock', 'dream pop']
# Bon_Jovi: ['Hard rock', 'pop rock', 'arena rock', 'glam metal']
# Phil_Collins: ['progressive rock', 'Pop', 'art rock<ref name="Phil Collins AllMusic" />', 'soft rock']
# The_Cab: ['power pop', 'Alternative rock', '<!-- All of these genres are sourced in the musical style section -->', 'pop', '{{nowrap|pop rock}}', '{{nowrap|emo pop}}', 'pop punk']
# Alice_in_Chains: ['{{nowrap|heavy metal}}', 'alternative metal', "<!--Don't add superfluous amount of subgenres as their style is perfectly elaborated in the main body of the article-->}}", 'alternative rock', 'sludge metal', 'Grunge']
# Led_Zeppelin: ['Hard rock', 'folk rock', 'heavy metal}}', 'blues rock', 'class=nowraplinks|']
# Nirvana__band_: ['<!--These genres are sourced in the article. Please do not add a genre without a reliable source or consensus on the talk page.-->', 'Grunge', 'alternative rock', '{{nowrap|punk rock}}']
# Heart__band_: ['folk rock', 'hard rock', 'pop rock}}', 'Rock']
# Billy_Idol: ['{{hlist|New wave|hard rock|pop rock|punk rock}}']
# Jim_Croce: ['{{hlist|Folk|soft rock}}']
# Third_Eye_Blind: ['{{nowrap|pop punk}}', '{{nowrap|power pop}}', '{{nowrap|Alternative rock}}', '{{nowrap|pop rock}}', '{{nowrap|post-grunge}}']
# Poison__American_band_: []
# Chevelle__band_: ['alternative metal', 'Hard rock', '{{nowrap|nu metal}}', 'alternative rock', '<!-- All of the following genres are sourced in the musical style section of the article. Please do not add unsourced genres. Please discuss before removing any genres. -->', 'post-grunge']
# AFI__band_: ['<!--- This is a summary', 'post-hardcore', 'gothic rock', 'hardcore punk (early)', 'not an exhaustive list; details are presented in the article text. Please discuss any changes on the talk page! --->', '{{nowrap|horror punk}}', 'Punk rock', 'emo']
# The_Clash: ['new wave', "<!--Please don't make any unexplained changes to", '{{nowrap|post-punk}}', 'genres. All genres have reliable citations. If you want to remove a genre', 'Punk rock', 'reggae', 'please make a consensus on the talk page first.-->', 'experimental rock']
# Little_River_Band: ['{{hlist|Rock|AOR|pop rock|soft rock}}']
# Joe_Satriani: ['Instrumental rock', 'hard rock', 'blues rock']
# Buckcherry: ['Hard rock', 'alternative metal', 'sleaze rock']
# W_A_S_P___band_: ['{{hlist|Heavy metal|{{nowrap|shock rock}}}}']
# Canned_Heat: ['{{Hlist|Blues rock|boogie rock}}']
# Creedence_Clearwater_Revival: ['roots rock', 'country rock', '<!--Genres listed here are sourced in the article text-->', 'blues rock', 'Southern rock', 'Swamp rock']
# Bowling_for_Soup: ['power pop', '<!---All genres are sourced in the musical style section.--->', 'Pop-punk', 'pop rock', '{{nowrap|alternative rock}}']
# The_Mothers_of_Invention: ['{{hlist|Jazz rock|experimental rock|progressive rock|comedy rock|blues rock|avant-garde|doo-wop|art rock}}']
# America__band_: ['{{hlist|Soft rock|folk rock|pop rock|country rock}}']
# Social_Distortion: ['cowpunk', '{{nowrap|rock and roll}}', 'hardcore punk (early)', 'Punk rock', '<!-- sourced in musical style / composition tab -->']
# Depeche_Mode: ['{{hlist|Synth-pop|alternative dance|alternative rock|dance-rock|dark wave|EDM|electronic rock|industrial|new wave|pop rock|post-punk}}']
# Sly_and_the_Family_Stone: ['rock', 'Psychedelic soul']
# Saving_Abel: ['hard rock', 'Southern rock', 'post-grunge', 'Rock']
# Melissa_Etheridge: ['{{hlist|Heartland rock|roots rock|folk rock|blues rock|country rock}}']
# The_Beatles: ['{{hlist|Rock|pop|beat|psychedelia}} <!--Based on talk page discussions and consensus. Please do not add other genres or sub-genres without first reaching consensus with other editors on the talk page. Thank you.-->']
# Loverboy: ['hard rock', '<!--Genres must be sourced. Up to four genres is sufficient per the template guidance-->', '{{nowrap|new wave (early)}}', 'pop rock', 'Arena rock']
# Bachman_Turner_Overdrive: ['{{hlist|Rock|hard rock|boogie rock}}']
# Ratt: ['Glam metal', 'hard rock', 'heavy metal']
# The_Black_Crowes: ['{{hlist|Southern rock|blues rock|hard rock|roots rock|jam band}}']
# Rage_Against_the_Machine: ['alternative metal', 'funk metal', 'rap rock', 'Rap metal', '<!-- Genres are sourced in the "musical style and influences" section-->']
# Janis_Joplin: ['{{hlist|Psychedelic rock|blues rock|soul|blues}}']
# Cage_the_Elephant: ['psychedelic rock', 'garage rock', 'Alternative rock', 'post-punk', 'punk blues', 'indie rock']
# Panic__at_the_Disco: ['Pop rock', 'emo', 'electropop', '<!-- All of these genres are sourced in the musical style section. Do not change without a source! Do not remove genres without an explanation! -->', 'pop-punk', 'baroque pop', '{{nowrap|alternative rock}}']
# Blondie__band_: ['disco', 'New wave', 'punk rock', 'pop', 'pop rock']
# My_Chemical_Romance: ['{{nowrap|hard rock}}', 'post-hardcore', '<!-- ALL THESE ARE SOURCED IN THE "MUSICAL STYLE" SECTION -->', 'Alternative rock', 'emo', '{{nowrap|pop-punk}}']
# Ghost__Swedish_band_: ['arena rock', 'heavy metal', '{{nowrap|progressive rock}}', 'Hard rock', 'pop rock']
# Black_Veil_Brides: ['{{nowrap|metalcore}}', 'alternative metal', 'Hard rock', '{{nowrap|gothic metal}}', '<!--- All genres added here must have at least 3 sources each in "Musical style and influences" section. --->', '{{nowrap|glam metal}}']
# Royal_Blood__band_: ['stoner rock', 'garage rock', 'Hard rock', 'blues rock', 'alternative rock']
# Daughtry__band_: ['Post-grunge', 'hard rock', 'pop rock']
# Damn_Yankees__band_: ['Hard rock', 'arena rock']
# Five_Finger_Death_Punch: ['Groove metal', 'alternative metal', '<!-- All of these genres are sourced in the musical style section. Do not change without a source. Do not remove genres without an explanation. -->', '{{nowrap|hard rock}}']
# Bill_Haley___His_Comets: ['{{hlist|Rock and roll|rockabilly|Western swing}}']
# Mumford___Sons: []
# Cream__band_: ['acid rock', 'blues rock', 'hard rock', 'Psychedelic rock']
# 311__band_: ['rap rock', 'Alternative rock', 'reggae rock', '<!--- Many genres are sourced. Only include genres that have at least 3 sources. --->{{Flatlist|', 'funk rock', 'funk metal']
# A_Perfect_Circle: ['{{nowrap|art rock}}', 'Alternative rock', '{{nowrap|alternative metal}}', 'hard rock', '<!----Do NOT edit this parameter without providing additional sources on the talk page BEFORE adding it here---->']
# Dr__Hook___the_Medicine_Show: ['{{hlist|Country rock|roots rock|boogie rock|pop rock|soft rock|blue-eyed soul|disco}}']
# Faces__band_: ['{{hlist|Rock|blues}}<!-- Please see Talk Page (archive) -->']
# Rod_Stewart: ['disco', 'blue-eyed soul', 'folk rock', 'traditional pop', 'blues rock', 'soft rock', 'pop', 'Rock']
# Bryan_Ferry: ['{{hlist|Pop rock|glam rock|art rock|sophisti-pop}}']
# The_Doors: ['<!-- Please restrain from adding/removing any genres. Template suggests to "preferably use 2-4". -->{{hlist|Psychedelic rock{{sfn|Debolt|Baugess|2011|pp=544–}}|{{nowrap|blues rock{{sfn|Wallace|2010|pp=68–}}}}|acid rock{{sfn|Einarson|2001|p=8}}}}']
# Stone_Sour: ['{{nowrap|hard rock}}', "<!-- All genres are sourced in the article's musical style section. Please do not add without sources. -->", 'Alternative metal', 'alternative rock', 'post-grunge']
# Lou_Reed: ['{{hlist|Rock|art rock|proto-punk|glam rock}}']
# The_White_Stripes: ['{{hlist|Garage rock|blues rock|alternative rock|punk blues|indie rock}}']
# Frank_Zappa: ['{{hlist|<!-- Do not add genres like art/prog/jazz/experimental/symphonic rock. This infobox would be enormous if every style Zappa ever played was included. -->Rock|progressive rock|blues|experimental|jazz|fusion|classical|pop|avant-garde|doo-wop|comedy|electronic|musique concrète}}']
# Puddle_of_Mudd: ['Post-grunge', 'hard rock', 'alternative rock']
# Glenn_Frey: ['{{hlist|Rock|pop rock|soft rock|country rock (early)|hard rock (later)}}']
# Flyleaf__band_: ['alternative metal', 'Alternative rock', 'hard rock', 'Christian rock', '<!-- All the following genres are cited to 5 or more sources under the section "Genre". Please do not add or change them without adding a good reference to that section or a talk page discussion. -->', 'post-grunge']
# Christopher_Cross: ['pop', 'yacht rock}}', 'soft rock', 'Rock']
# Lenny_Kravitz: ['funk', 'soul', 'Rock']
# Lynyrd_Skynyrd: ['{{hlist|Southern rock|blues rock|country rock|hard rock}}']
# Creed__band_: ['alternative metal', 'or without first discussing on the talk page --->', 'hard rock', '<!-- Do NOT add "Christian music" or "Christian rock" as the band has stated on multiple occasions that they are a Christian band', 'were they signed to a Christian record label; do not add "pop rock" as that could be disputed; do not add or change genres without a reference', 'Post-grunge', '{{nowrap|alternative rock}}']
# Everclear__band_: ['power pop', 'Alternative rock', 'punk rock (early)', 'pop rock', '{{nowrap|grunge (early)}}', '{{nowrap|post-grunge}}']
# Weezer: ['power pop', '<!-- Genres are sourced in the "Musical style and influences" section. Do NOT remove sourced genres. Only add genres with reliable sources. Timelines should not be included in an infobox. -->', 'geek rock', 'Alternative rock', 'pop-punk', 'pop rock', 'as it is sourced. Any removals of this genre without discussion will be reverted.--->emo', '<!---Do NOT remove emo']
# Thousand_Foot_Krutch: ['heavy metal', 'hard rock', 'Christian rock', 'alternative rock', 'Christian metal', 'rap metal<ref name="allmusic1" />', '{{Nowrap|nu metal}}']
# John_Mayall___the_Bluesbreakers: ['British blues', 'blues rock', 'jazz&nbsp;rock']
# Foster_the_People: ['synth-pop', '{{nowrap|neo-psychedelia}}', 'alternative rock', 'indie rock', 'Indie pop', 'dance-pop']
# Deep_Purple: ['<!--Do not add unsourced genres-->{{hlist|Hard rock|heavy metal|progressive rock}}']
# The_Strokes: ['<!-- these genres are sourced in the musical style section of the text -->{{hlist|Indie rock|garage rock revival|post-punk revival|new wave|synth-pop}}']
# Train__band_: ['alternative rock', 'roots rock', 'pop rock', 'Rock']
# INXS: ['New wave', 'pub rock', 'alternative rock', 'funk rock', 'dance-rock']
# Bob_Seger: ['{{hlist|Rock|heartland rock|roots rock}}']
# The_Black_Keys: ['indie rock', '{{nowrap|punk blues}}', "Garage rock <!-- please don't add any unsourced genres -->", 'blues rock']
# Roy_Orbison: ['{{hlist|Rock|pop|country|rock and roll|rockabilly}}']
# 3_Doors_Down: ['Post-grunge', 'alternative rock']
# The_Alan_Parsons_Project: ['{{hlist|Progressive rock|art rock|progressive pop|soft rock}}']
# The_Stone_Roses: ['{{hlist|Madchester|indie rock|alternative rock|dance-rock|neo-psychedelia}}']
# Meat_Loaf: ['hard rock', 'Rock']
# Dallas_Green__musician_: []
# Quiet_Riot: ['hard rock', 'Heavy metal', 'glam metal']
# The_B-52_s: []
# Rush__band_: ['heavy metal', 'Progressive rock', 'hard rock', 'do not add alternative rock -->', '<!-- only primary genres']
# Rainbow__rock_band_: ['{{hlist|Hard rock|heavy metal}}']
# Joe_Cocker: ['{{Hlist|Rock|blues|blue-eyed soul|pop}}']
# Barenaked_Ladies: ['<!-- should not be changed or added to without discussion on talk page-->', 'folk rock', 'Alternative pop<ref name=AllMusic/>', 'pop rock', 'comedy rock']
# Modest_Mouse: ['Indie rock', 'punk rock', 'alternative rock', 'post punk revival', 'emo (early)']
# The_Tragically_Hip: ['folk rock', 'roots rock', 'Alternative rock']
# Genesis__band_: ['art rock', 'Progressive rock', 'pop rock', 'soft rock']
# Duane_Eddy: ['{{hlist|Instrumental rock|rockabilly|rock and roll|country}}']
# Nickelback: ['alternative metal', 'hard rock', '<!--All genres sourced in the "Musical styles" section.-->', 'pop rock', 'Post-grunge', '{{nowrap|alternative rock}}']
# Pop_Evil: ['Hard rock', 'alternative metal', 'post-grunge']
# The_Lovin__Spoonful: ['{{hlist|{{nowrap|Folk rock}}|pop|rock}}']
# Don_Henley: ['{{hlist|Rock|country rock|pop rock|hard rock|folk rock}}']
# Ben_Folds_Five: ['power pop', 'Alternative rock']
# REO_Speedwagon: ['{{hlist|Arena rock|pop rock|hard rock|AOR|blues rock (early)}}']
# Living_Colour: ['Hard rock', 'alternative metal', 'funk metal']
# 38_Special__band_: ['{{hlist|Hard rock||southern rock|boogie rock|blues rock}}']
# Sheryl_Crow: ['folk', 'blues', 'Country rock', 'pop', 'heartland rock']
# The_Used: ['<!-- these genres are sourced in the "musical style" section of the text; please don\'t change them without providing further sources or discussing changes on the talk page -->', 'screamo', 'Emo', 'punk rock', 'pop-punk', '{{nowrap|post-hardcore}}', 'alternative rock']
# James_Taylor: ['{{hlist|Soft rock|folk}}']
# Emerson__Lake___Palmer: []
# Cinderella__band_: ['Glam metal', 'hard rock', '{{nowrap|blues rock}}']
# Simple_Minds: ['{{hlist|Post-punk|art rock|synth-pop}}']
# The_Rolling_Stones: ['blues', '<!--These genres have been decided after much discussion. Please do not change without prior consensus.-->', 'pop', 'Rock']
# Chris_de_Burgh: ['pop', 'Art rock']
# Pink_Floyd: ['psychedelic rock', 'space rock', 'art rock', 'Progressive rock', 'experimental rock']
# Eddie_Cochran: ['rhythm and blues', 'Rock and roll', 'country', 'rockabilly']
# Primus__band_: ['Alternative metal', 'funk metal', 'progressive rock', 'experimental rock']
# The_Script: ['{{hlist|Pop rock|soft rock|indie rock}}']
# Warrant__American_band_: ['Glam metal', 'hard rock', 'heavy metal']
# The_Smiths: ['{{hlist|', 'Indie pop|indie rock|jangle pop|alternative rock}}']
# The_Mamas___the_Papas: ['{{hlist|Pop|Soul}}']
# Rammstein: ['industrial metal', '{{Lang|de|Neue Deutsche Härte|italic=no}}', '<!--Genres are sourced in the body-->']
# Hootie___the_Blowfish: []
# Blur__band_: ['indie rock', 'alternative rock', 'art pop', 'Britpop']
